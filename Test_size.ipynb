# %% [markdown]
# # ============================================================
# # EEG FEW-SHOT LEARNING FRAMEWORK
# # Sobel + Attention + KAN + Deep Supervision
# # ============================================================

# %% [markdown]
# # **Test Size**

# %% [markdown]
# # test_size=**0.1**

# %%
# ============================================================
# EEG FEW-SHOT LEARNING FRAMEWORK
# Sobel + Attention + KAN + Deep Supervision
# Train/Validation + ROC + PR + IEEE Figures
# ============================================================

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    auc,
    precision_recall_curve
)

# ============================================================
# DEVICE
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# LOAD DATA
# ============================================================

mat = sio.loadmat("SEED_VIG.mat")

X = mat["EEGsample"].astype(np.float32)
y = mat["substate"].squeeze()

X = (X - X.mean()) / (X.std() + 1e-6)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.1, random_state=42, stratify=y
)

# ============================================================
# DATASET
# ============================================================

class EEGDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_loader = DataLoader(EEGDataset(X_train, y_train), batch_size=32, shuffle=True)
val_loader   = DataLoader(EEGDataset(X_val, y_val), batch_size=32, shuffle=False)

# ============================================================
# SOBEL PROJECTION
# ============================================================

class Sobel1D(nn.Module):
    def __init__(self):
        super().__init__()
        k = torch.tensor([[[-1, 0, 1]]], dtype=torch.float32)
        self.weight = nn.Parameter(k, requires_grad=False)

    def forward(self, x):
        B, C, T = x.shape
        out = []
        for c in range(C):
            out.append(F.conv1d(x[:, c:c+1], self.weight, padding=1))
        return torch.cat(out, dim=1).abs()

# ============================================================
# ATTENTION
# ============================================================

class Attention1D(nn.Module):
    def __init__(self, C, r=8):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(C, C // r)
        self.fc2 = nn.Linear(C // r, C)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        B, C, T = x.shape
        y = self.pool(x).view(B, C)
        y = F.relu(self.fc1(y))
        y = self.sigmoid(self.fc2(y)).view(B, C, 1)
        return x * y

# ============================================================
# KAN MIXER
# ============================================================

class KAN(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.fc1 = nn.Linear(dim, dim * 2)
        self.fc2 = nn.Linear(dim * 2, dim)
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        r = x
        x = self.norm(x)
        x = F.gelu(self.fc1(x))
        x = self.fc2(x)
        return x + r

# ============================================================
# ENCODER
# ============================================================

class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.sobel = Sobel1D()

        self.conv1 = nn.Conv1d(17, 32, 5, padding=2)
        self.conv2 = nn.Conv1d(32, 64, 5, padding=2)
        self.conv3 = nn.Conv1d(64, 128, 5, padding=2)

        self.bn1 = nn.BatchNorm1d(32)
        self.bn2 = nn.BatchNorm1d(64)
        self.bn3 = nn.BatchNorm1d(128)

        self.att1 = Attention1D(32)
        self.att2 = Attention1D(64)
        self.att3 = Attention1D(128)

        self.pool = nn.MaxPool1d(2)

        self.kan = KAN(128)

        self.ds1 = nn.Linear(32, num_classes)
        self.ds2 = nn.Linear(64, num_classes)
        self.ds3 = nn.Linear(128, num_classes)

    def forward(self, x):

        x = x + self.sobel(x)

        x1 = self.pool(self.att1(F.relu(self.bn1(self.conv1(x)))))
        x2 = self.pool(self.att2(F.relu(self.bn2(self.conv2(x1)))))
        x3 = self.pool(self.att3(F.relu(self.bn3(self.conv3(x2)))))

        f1 = F.adaptive_avg_pool1d(x1, 1).squeeze(-1)
        f2 = F.adaptive_avg_pool1d(x2, 1).squeeze(-1)
        f3 = F.adaptive_avg_pool1d(x3, 1).squeeze(-1)

        f3 = self.kan(f3)

        return f3, self.ds1(f1), self.ds2(f2), self.ds3(f3)

# ============================================================
# MODEL
# ============================================================

num_classes = len(np.unique(y))

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.enc = Encoder(num_classes)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        f, d1, d2, d3 = self.enc(x)
        return self.fc(f), [d1, d2, d3]

model = Model().to(device)

# ============================================================
# LOSS + OPT
# ============================================================

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# ============================================================
# HISTORY
# ============================================================

history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": [],
    "train_f1": [],
    "val_f1": []
}

# ============================================================
# TRAINING
# ============================================================

start_time = datetime.now()
num_epochs = 100

for epoch in range(num_epochs):

    # ================= TRAIN =================
    model.train()
    train_p, train_y = [], []
    train_loss = 0

    for x, yb in train_loader:
        x, yb = x.to(device), yb.to(device)

        optimizer.zero_grad()

        logits, ds = model(x)

        loss = criterion(logits, yb)
        for d in ds:
            loss += 0.3 * criterion(d, yb)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        train_p.extend(torch.argmax(logits, 1).cpu().numpy())
        train_y.extend(yb.cpu().numpy())

    # ================= VAL =================
    model.eval()
    val_p, val_y = [], []
    val_loss = 0

    with torch.no_grad():
        for x, yb in val_loader:
            x, yb = x.to(device), yb.to(device)

            logits, _ = model(x)

            loss = criterion(logits, yb)
            val_loss += loss.item()

            val_p.extend(torch.argmax(logits, 1).cpu().numpy())
            val_y.extend(yb.cpu().numpy())

    # ================= METRICS =================
    tr_acc = accuracy_score(train_y, train_p) * 100
    va_acc = accuracy_score(val_y, val_p) * 100

    tr_f1 = f1_score(train_y, train_p, average='weighted')
    va_f1 = f1_score(val_y, val_p, average='weighted')

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(va_acc)
    history["train_f1"].append(tr_f1)
    history["val_f1"].append(va_f1)

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Loss:{train_loss:.4f} "
          f"Train Acc:{tr_acc:.2f}% "
          f"Val Acc:{va_acc:.2f}% "
          f"Train F1:{tr_f1:.4f} "
          f"Val F1:{va_f1:.4f}")

print("Training time:", datetime.now() - start_time)

# ============================================================
# VISUALIZATION (BLUE=VAL, ORANGE=TRAIN)
# ============================================================

epochs = range(num_epochs)

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

# LOSS
ax[0,0].plot(history["train_loss"], color='orange')
ax[0,0].plot(history["val_loss"], color='blue')
ax[0,0].set_title("Loss")

# ACC
ax[0,1].plot(history["train_acc"], color='orange')
ax[0,1].plot(history["val_acc"], color='blue')
ax[0,1].set_title("Accuracy")

# F1
ax[0,2].plot(history["train_f1"], color='orange')
ax[0,2].plot(history["val_f1"], color='blue')
ax[0,2].set_title("F1-score")

plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Epoch 1/100 - Loss:112.1516 Train Acc:83.69% Val Acc:88.40% Train F1:0.8369 Val F1:0.8829
# Epoch 2/100 - Loss:87.6253 Train Acc:89.41% Val Acc:54.49% Train F1:0.8941 Val F1:0.4279
# Epoch 3/100 - Loss:74.7439 Train Acc:91.75% Val Acc:56.24% Train F1:0.9175 Val F1:0.4605
# Epoch 4/100 - Loss:73.2759 Train Acc:91.02% Val Acc:55.58% Train F1:0.9102 Val F1:0.4458
# Epoch 5/100 - Loss:64.4664 Train Acc:93.31% Val Acc:61.71% Train F1:0.9331 Val F1:0.5525
# Epoch 6/100 - Loss:60.2509 Train Acc:93.11% Val Acc:81.18% Train F1:0.9311 Val F1:0.8109
# Epoch 7/100 - Loss:56.6697 Train Acc:93.96% Val Acc:71.12% Train F1:0.9396 Val F1:0.6855
# Epoch 8/100 - Loss:55.7963 Train Acc:93.94% Val Acc:70.90% Train F1:0.9394 Val F1:0.6827
# Epoch 9/100 - Loss:56.9221 Train Acc:93.72% Val Acc:91.25% Train F1:0.9372 Val F1:0.9118
# Epoch 10/100 - Loss:52.5415 Train Acc:94.04% Val Acc:91.90% Train F1:0.9403 Val F1:0.9185
# Epoch 11/100 - Loss:50.4013 Train Acc:94.99% Val Acc:53.17% Train F1:0.9499 Val F1:0.4024
# Epoch 12/100 - Loss:46.8541 Train Acc:94.99% Val Acc:81.62% Train F1:0.9499 Val F1:0.8117
# Epoch 13/100 - Loss:46.3629 Train Acc:95.23% Val Acc:91.47% Train F1:0.9523 Val F1:0.9141
# Epoch 14/100 - Loss:47.4050 Train Acc:95.42% Val Acc:86.43% Train F1:0.9542 Val F1:0.8621
# Epoch 15/100 - Loss:42.9392 Train Acc:96.01% Val Acc:93.87% Train F1:0.9601 Val F1:0.9386
# Epoch 16/100 - Loss:44.4244 Train Acc:95.42% Val Acc:66.74% Train F1:0.9542 Val F1:0.6269
# Epoch 17/100 - Loss:43.0753 Train Acc:95.30% Val Acc:92.56% Train F1:0.9530 Val F1:0.9253
# Epoch 18/100 - Loss:40.2896 Train Acc:96.03% Val Acc:93.22% Train F1:0.9603 Val F1:0.9319
# Epoch 19/100 - Loss:37.8556 Train Acc:96.33% Val Acc:77.24% Train F1:0.9632 Val F1:0.7604
# Epoch 20/100 - Loss:41.1612 Train Acc:95.52% Val Acc:88.84% Train F1:0.9552 Val F1:0.8871
# Epoch 21/100 - Loss:37.8249 Train Acc:96.30% Val Acc:85.12% Train F1:0.9630 Val F1:0.8484
# Epoch 22/100 - Loss:37.8617 Train Acc:96.25% Val Acc:94.09% Train F1:0.9625 Val F1:0.9409
# Epoch 23/100 - Loss:34.9245 Train Acc:96.79% Val Acc:86.00% Train F1:0.9679 Val F1:0.8575
# Epoch 24/100 - Loss:34.6498 Train Acc:96.88% Val Acc:91.90% Train F1:0.9688 Val F1:0.9187
# Epoch 25/100 - Loss:35.3639 Train Acc:96.57% Val Acc:66.30% Train F1:0.9657 Val F1:0.6208
# Epoch 26/100 - Loss:34.7842 Train Acc:97.25% Val Acc:70.02% Train F1:0.9725 Val F1:0.6790
# Epoch 27/100 - Loss:33.3838 Train Acc:97.06% Val Acc:91.68% Train F1:0.9706 Val F1:0.9164
# Epoch 28/100 - Loss:32.8774 Train Acc:97.32% Val Acc:90.15% Train F1:0.9732 Val F1:0.9009
# Epoch 29/100 - Loss:34.3390 Train Acc:97.18% Val Acc:85.78% Train F1:0.9718 Val F1:0.8550
# Epoch 30/100 - Loss:29.5528 Train Acc:97.74% Val Acc:74.40% Train F1:0.9774 Val F1:0.7271
# Epoch 31/100 - Loss:30.8853 Train Acc:97.37% Val Acc:87.09% Train F1:0.9737 Val F1:0.8690
# Epoch 32/100 - Loss:30.8915 Train Acc:97.69% Val Acc:76.59% Train F1:0.9769 Val F1:0.7527
# Epoch 33/100 - Loss:30.5995 Train Acc:97.18% Val Acc:84.25% Train F1:0.9718 Val F1:0.8386
# Epoch 34/100 - Loss:29.3041 Train Acc:97.96% Val Acc:93.22% Train F1:0.9796 Val F1:0.9321
# Epoch 35/100 - Loss:31.3368 Train Acc:97.37% Val Acc:92.12% Train F1:0.9737 Val F1:0.9210
# Epoch 36/100 - Loss:29.2100 Train Acc:97.76% Val Acc:91.90% Train F1:0.9776 Val F1:0.9186
# Epoch 37/100 - Loss:31.4686 Train Acc:97.42% Val Acc:87.53% Train F1:0.9742 Val F1:0.8733
# Epoch 38/100 - Loss:33.9499 Train Acc:96.86% Val Acc:93.87% Train F1:0.9686 Val F1:0.9385
# Epoch 39/100 - Loss:28.3117 Train Acc:97.69% Val Acc:94.97% Train F1:0.9769 Val F1:0.9496
# Epoch 40/100 - Loss:25.3351 Train Acc:98.54% Val Acc:89.93% Train F1:0.9854 Val F1:0.8991
# Epoch 41/100 - Loss:25.4267 Train Acc:98.27% Val Acc:92.78% Train F1:0.9827 Val F1:0.9275
# Epoch 42/100 - Loss:25.8804 Train Acc:98.35% Val Acc:93.87% Train F1:0.9835 Val F1:0.9387
# Epoch 43/100 - Loss:26.1156 Train Acc:98.27% Val Acc:94.53% Train F1:0.9827 Val F1:0.9453
# Epoch 44/100 - Loss:24.2002 Train Acc:98.35% Val Acc:60.83% Train F1:0.9835 Val F1:0.5387
# Epoch 45/100 - Loss:23.8919 Train Acc:98.76% Val Acc:93.44% Train F1:0.9876 Val F1:0.9343
# Epoch 46/100 - Loss:26.2695 Train Acc:98.20% Val Acc:93.87% Train F1:0.9820 Val F1:0.9387
# Epoch 47/100 - Loss:25.4856 Train Acc:98.20% Val Acc:51.20% Train F1:0.9820 Val F1:0.3584
# Epoch 48/100 - Loss:22.2441 Train Acc:98.81% Val Acc:94.75% Train F1:0.9881 Val F1:0.9475
# Epoch 49/100 - Loss:25.1425 Train Acc:98.44% Val Acc:90.37% Train F1:0.9844 Val F1:0.9030
# Epoch 50/100 - Loss:22.7370 Train Acc:98.69% Val Acc:93.44% Train F1:0.9869 Val F1:0.9343
# Epoch 51/100 - Loss:23.4164 Train Acc:98.69% Val Acc:93.87% Train F1:0.9869 Val F1:0.9386
# Epoch 52/100 - Loss:22.3665 Train Acc:98.83% Val Acc:93.44% Train F1:0.9883 Val F1:0.9342
# Epoch 53/100 - Loss:26.9230 Train Acc:98.10% Val Acc:83.59% Train F1:0.9810 Val F1:0.8340
# Epoch 54/100 - Loss:23.7783 Train Acc:98.56% Val Acc:58.21% Train F1:0.9856 Val F1:0.4974
# Epoch 55/100 - Loss:22.8799 Train Acc:98.90% Val Acc:83.81% Train F1:0.9890 Val F1:0.8367
# Epoch 56/100 - Loss:22.5414 Train Acc:98.59% Val Acc:71.33% Train F1:0.9859 Val F1:0.6997
# Epoch 57/100 - Loss:22.0676 Train Acc:98.98% Val Acc:50.33% Train F1:0.9898 Val F1:0.3432
# Epoch 58/100 - Loss:21.1547 Train Acc:99.15% Val Acc:52.95% Train F1:0.9915 Val F1:0.3980
# Epoch 59/100 - Loss:23.1305 Train Acc:98.73% Val Acc:83.37% Train F1:0.9873 Val F1:0.8292
# Epoch 60/100 - Loss:20.2475 Train Acc:99.29% Val Acc:92.56% Train F1:0.9929 Val F1:0.9253
# Epoch 61/100 - Loss:22.1876 Train Acc:98.71% Val Acc:84.90% Train F1:0.9871 Val F1:0.8462
# Epoch 62/100 - Loss:21.2891 Train Acc:98.90% Val Acc:93.65% Train F1:0.9890 Val F1:0.9363
# Epoch 63/100 - Loss:20.1123 Train Acc:99.10% Val Acc:93.87% Train F1:0.9910 Val F1:0.9387
# Epoch 64/100 - Loss:21.7733 Train Acc:98.73% Val Acc:90.59% Train F1:0.9873 Val F1:0.9052
# Epoch 65/100 - Loss:18.4947 Train Acc:99.44% Val Acc:93.44% Train F1:0.9944 Val F1:0.9342
# Epoch 66/100 - Loss:22.6011 Train Acc:98.59% Val Acc:57.77% Train F1:0.9859 Val F1:0.4943
# Epoch 67/100 - Loss:18.1479 Train Acc:99.54% Val Acc:87.53% Train F1:0.9954 Val F1:0.8743
# Epoch 68/100 - Loss:19.3164 Train Acc:99.27% Val Acc:94.97% Train F1:0.9927 Val F1:0.9496
# Epoch 69/100 - Loss:19.9971 Train Acc:99.25% Val Acc:91.03% Train F1:0.9925 Val F1:0.9101
# Epoch 70/100 - Loss:18.0255 Train Acc:99.61% Val Acc:73.96% Train F1:0.9961 Val F1:0.7218
# Epoch 71/100 - Loss:20.3877 Train Acc:99.15% Val Acc:89.06% Train F1:0.9915 Val F1:0.8903
# Epoch 72/100 - Loss:19.6366 Train Acc:99.17% Val Acc:90.59% Train F1:0.9917 Val F1:0.9052
# Epoch 73/100 - Loss:16.8342 Train Acc:99.54% Val Acc:59.08% Train F1:0.9954 Val F1:0.5100
# Epoch 74/100 - Loss:19.7136 Train Acc:99.17% Val Acc:70.02% Train F1:0.9917 Val F1:0.6740
# Epoch 75/100 - Loss:19.2635 Train Acc:99.15% Val Acc:81.84% Train F1:0.9915 Val F1:0.8169
# Epoch 76/100 - Loss:19.2698 Train Acc:99.20% Val Acc:92.78% Train F1:0.9920 Val F1:0.9276
# Epoch 77/100 - Loss:18.3279 Train Acc:99.59% Val Acc:93.44% Train F1:0.9959 Val F1:0.9341
# Epoch 78/100 - Loss:19.3581 Train Acc:99.03% Val Acc:95.19% Train F1:0.9903 Val F1:0.9518
# Epoch 79/100 - Loss:18.3939 Train Acc:99.29% Val Acc:94.97% Train F1:0.9929 Val F1:0.9496
# Epoch 80/100 - Loss:17.9982 Train Acc:99.34% Val Acc:93.87% Train F1:0.9934 Val F1:0.9385
# Epoch 81/100 - Loss:18.7162 Train Acc:99.27% Val Acc:92.12% Train F1:0.9927 Val F1:0.9208
# Epoch 82/100 - Loss:20.4342 Train Acc:99.12% Val Acc:96.06% Train F1:0.9912 Val F1:0.9606
# Epoch 83/100 - Loss:18.5797 Train Acc:99.32% Val Acc:72.21% Train F1:0.9932 Val F1:0.7002
# Epoch 84/100 - Loss:18.0095 Train Acc:99.39% Val Acc:62.36% Train F1:0.9939 Val F1:0.5627
# Epoch 85/100 - Loss:16.6030 Train Acc:99.22% Val Acc:91.03% Train F1:0.9922 Val F1:0.9096
# Epoch 86/100 - Loss:17.2271 Train Acc:99.46% Val Acc:74.62% Train F1:0.9946 Val F1:0.7422
# Epoch 87/100 - Loss:19.9397 Train Acc:99.34% Val Acc:94.97% Train F1:0.9934 Val F1:0.9496
# Epoch 88/100 - Loss:17.1797 Train Acc:99.29% Val Acc:81.62% Train F1:0.9929 Val F1:0.8131
# Epoch 89/100 - Loss:17.6155 Train Acc:99.54% Val Acc:75.27% Train F1:0.9954 Val F1:0.7482
# Epoch 90/100 - Loss:15.2409 Train Acc:99.59% Val Acc:55.36% Train F1:0.9959 Val F1:0.4444
# Epoch 91/100 - Loss:18.8935 Train Acc:99.08% Val Acc:55.36% Train F1:0.9908 Val F1:0.4497
# Epoch 92/100 - Loss:17.8886 Train Acc:99.32% Val Acc:63.24% Train F1:0.9932 Val F1:0.5849
# Epoch 93/100 - Loss:16.2113 Train Acc:99.68% Val Acc:94.09% Train F1:0.9968 Val F1:0.9409
# Epoch 94/100 - Loss:15.2554 Train Acc:99.42% Val Acc:83.15% Train F1:0.9942 Val F1:0.8273
# Epoch 95/100 - Loss:16.9032 Train Acc:99.34% Val Acc:68.71% Train F1:0.9934 Val F1:0.6624
# Epoch 96/100 - Loss:16.5704 Train Acc:99.44% Val Acc:91.25% Train F1:0.9944 Val F1:0.9119
# Epoch 97/100 - Loss:16.6268 Train Acc:99.68% Val Acc:67.18% Train F1:0.9968 Val F1:0.6318
# Epoch 98/100 - Loss:17.0282 Train Acc:99.44% Val Acc:92.12% Train F1:0.9944 Val F1:0.9212
# Epoch 99/100 - Loss:16.6845 Train Acc:99.49% Val Acc:92.34% Train F1:0.9949 Val F1:0.9230
# Epoch 100/100 - Loss:16.6613 Train Acc:99.46% Val Acc:93.22% Train F1:0.9946 Val F1:0.9321
# Training time: 0:02:31.013133

# %% [markdown]
# # **test_size**=0.3

# %%
# ============================================================
# EEG FEW-SHOT LEARNING FRAMEWORK
# Sobel + Attention + KAN + Deep Supervision
# Train/Validation + ROC + PR + IEEE Figures
# ============================================================

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    auc,
    precision_recall_curve
)

# ============================================================
# DEVICE
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# LOAD DATA
# ============================================================

mat = sio.loadmat("SEED_VIG.mat")

X = mat["EEGsample"].astype(np.float32)
y = mat["substate"].squeeze()

X = (X - X.mean()) / (X.std() + 1e-6)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ============================================================
# DATASET
# ============================================================

class EEGDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_loader = DataLoader(EEGDataset(X_train, y_train), batch_size=32, shuffle=True)
val_loader   = DataLoader(EEGDataset(X_val, y_val), batch_size=32, shuffle=False)

# ============================================================
# SOBEL PROJECTION
# ============================================================

class Sobel1D(nn.Module):
    def __init__(self):
        super().__init__()
        k = torch.tensor([[[-1, 0, 1]]], dtype=torch.float32)
        self.weight = nn.Parameter(k, requires_grad=False)

    def forward(self, x):
        B, C, T = x.shape
        out = []
        for c in range(C):
            out.append(F.conv1d(x[:, c:c+1], self.weight, padding=1))
        return torch.cat(out, dim=1).abs()

# ============================================================
# ATTENTION
# ============================================================

class Attention1D(nn.Module):
    def __init__(self, C, r=8):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(C, C // r)
        self.fc2 = nn.Linear(C // r, C)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        B, C, T = x.shape
        y = self.pool(x).view(B, C)
        y = F.relu(self.fc1(y))
        y = self.sigmoid(self.fc2(y)).view(B, C, 1)
        return x * y

# ============================================================
# KAN MIXER
# ============================================================

class KAN(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.fc1 = nn.Linear(dim, dim * 2)
        self.fc2 = nn.Linear(dim * 2, dim)
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        r = x
        x = self.norm(x)
        x = F.gelu(self.fc1(x))
        x = self.fc2(x)
        return x + r

# ============================================================
# ENCODER
# ============================================================

class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.sobel = Sobel1D()

        self.conv1 = nn.Conv1d(17, 32, 5, padding=2)
        self.conv2 = nn.Conv1d(32, 64, 5, padding=2)
        self.conv3 = nn.Conv1d(64, 128, 5, padding=2)

        self.bn1 = nn.BatchNorm1d(32)
        self.bn2 = nn.BatchNorm1d(64)
        self.bn3 = nn.BatchNorm1d(128)

        self.att1 = Attention1D(32)
        self.att2 = Attention1D(64)
        self.att3 = Attention1D(128)

        self.pool = nn.MaxPool1d(2)

        self.kan = KAN(128)

        self.ds1 = nn.Linear(32, num_classes)
        self.ds2 = nn.Linear(64, num_classes)
        self.ds3 = nn.Linear(128, num_classes)

    def forward(self, x):

        x = x + self.sobel(x)

        x1 = self.pool(self.att1(F.relu(self.bn1(self.conv1(x)))))
        x2 = self.pool(self.att2(F.relu(self.bn2(self.conv2(x1)))))
        x3 = self.pool(self.att3(F.relu(self.bn3(self.conv3(x2)))))

        f1 = F.adaptive_avg_pool1d(x1, 1).squeeze(-1)
        f2 = F.adaptive_avg_pool1d(x2, 1).squeeze(-1)
        f3 = F.adaptive_avg_pool1d(x3, 1).squeeze(-1)

        f3 = self.kan(f3)

        return f3, self.ds1(f1), self.ds2(f2), self.ds3(f3)

# ============================================================
# MODEL
# ============================================================

num_classes = len(np.unique(y))

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.enc = Encoder(num_classes)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        f, d1, d2, d3 = self.enc(x)
        return self.fc(f), [d1, d2, d3]

model = Model().to(device)

# ============================================================
# LOSS + OPT
# ============================================================

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# ============================================================
# HISTORY
# ============================================================

history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": [],
    "train_f1": [],
    "val_f1": []
}

# ============================================================
# TRAINING
# ============================================================

start_time = datetime.now()
num_epochs = 100

for epoch in range(num_epochs):

    # ================= TRAIN =================
    model.train()
    train_p, train_y = [], []
    train_loss = 0

    for x, yb in train_loader:
        x, yb = x.to(device), yb.to(device)

        optimizer.zero_grad()

        logits, ds = model(x)

        loss = criterion(logits, yb)
        for d in ds:
            loss += 0.3 * criterion(d, yb)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        train_p.extend(torch.argmax(logits, 1).cpu().numpy())
        train_y.extend(yb.cpu().numpy())

    # ================= VAL =================
    model.eval()
    val_p, val_y = [], []
    val_loss = 0

    with torch.no_grad():
        for x, yb in val_loader:
            x, yb = x.to(device), yb.to(device)

            logits, _ = model(x)

            loss = criterion(logits, yb)
            val_loss += loss.item()

            val_p.extend(torch.argmax(logits, 1).cpu().numpy())
            val_y.extend(yb.cpu().numpy())

    # ================= METRICS =================
    tr_acc = accuracy_score(train_y, train_p) * 100
    va_acc = accuracy_score(val_y, val_p) * 100

    tr_f1 = f1_score(train_y, train_p, average='weighted')
    va_f1 = f1_score(val_y, val_p, average='weighted')

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(va_acc)
    history["train_f1"].append(tr_f1)
    history["val_f1"].append(va_f1)

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Loss:{train_loss:.4f} "
          f"Train Acc:{tr_acc:.2f}% "
          f"Val Acc:{va_acc:.2f}% "
          f"Train F1:{tr_f1:.4f} "
          f"Val F1:{va_f1:.4f}")

print("Training time:", datetime.now() - start_time)

# ============================================================
# VISUALIZATION (BLUE=VAL, ORANGE=TRAIN)
# ============================================================

epochs = range(num_epochs)

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

# LOSS
ax[0,0].plot(history["train_loss"], color='orange')
ax[0,0].plot(history["val_loss"], color='blue')
ax[0,0].set_title("Loss")

# ACC
ax[0,1].plot(history["train_acc"], color='orange')
ax[0,1].plot(history["val_acc"], color='blue')
ax[0,1].set_title("Accuracy")

# F1
ax[0,2].plot(history["train_f1"], color='orange')
ax[0,2].plot(history["val_f1"], color='blue')
ax[0,2].set_title("F1-score")

plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Epoch 1/100 - Loss:87.3241 Train Acc:83.26% Val Acc:88.83% Train F1:0.8326 Val F1:0.8881
# Epoch 2/100 - Loss:66.9679 Train Acc:90.52% Val Acc:91.24% Train F1:0.9051 Val F1:0.9123
# Epoch 3/100 - Loss:60.1217 Train Acc:91.90% Val Acc:85.47% Train F1:0.9190 Val F1:0.8531
# Epoch 4/100 - Loss:55.7271 Train Acc:92.24% Val Acc:60.15% Train F1:0.9224 Val F1:0.5356
# Epoch 5/100 - Loss:50.2960 Train Acc:92.90% Val Acc:54.01% Train F1:0.9290 Val F1:0.4198
# Epoch 6/100 - Loss:47.2458 Train Acc:93.65% Val Acc:88.18% Train F1:0.9365 Val F1:0.8809
# Epoch 7/100 - Loss:43.7176 Train Acc:94.71% Val Acc:67.74% Train F1:0.9471 Val F1:0.6428
# Epoch 8/100 - Loss:46.2282 Train Acc:93.55% Val Acc:50.00% Train F1:0.9355 Val F1:0.3333
# Epoch 9/100 - Loss:43.2132 Train Acc:94.62% Val Acc:81.82% Train F1:0.9462 Val F1:0.8126
# Epoch 10/100 - Loss:39.2458 Train Acc:94.84% Val Acc:50.80% Train F1:0.9484 Val F1:0.3509
# Epoch 11/100 - Loss:36.1391 Train Acc:95.56% Val Acc:75.62% Train F1:0.9556 Val F1:0.7425
# Epoch 12/100 - Loss:38.0398 Train Acc:95.62% Val Acc:50.44% Train F1:0.9562 Val F1:0.3442
# Epoch 13/100 - Loss:38.3058 Train Acc:95.09% Val Acc:93.65% Train F1:0.9509 Val F1:0.9365
# Epoch 14/100 - Loss:35.2348 Train Acc:95.59% Val Acc:92.19% Train F1:0.9559 Val F1:0.9217
# Epoch 15/100 - Loss:34.4035 Train Acc:95.81% Val Acc:91.61% Train F1:0.9581 Val F1:0.9157
# Epoch 16/100 - Loss:35.0172 Train Acc:96.09% Val Acc:51.24% Train F1:0.9609 Val F1:0.3627
# Epoch 17/100 - Loss:35.8629 Train Acc:94.65% Val Acc:90.58% Train F1:0.9465 Val F1:0.9057
# Epoch 18/100 - Loss:32.2298 Train Acc:96.21% Val Acc:94.60% Train F1:0.9621 Val F1:0.9459
# Epoch 19/100 - Loss:33.3848 Train Acc:95.78% Val Acc:61.39% Train F1:0.9578 Val F1:0.5548
# Epoch 20/100 - Loss:29.7678 Train Acc:96.71% Val Acc:86.64% Train F1:0.9671 Val F1:0.8645
# Epoch 21/100 - Loss:30.3732 Train Acc:96.34% Val Acc:83.94% Train F1:0.9634 Val F1:0.8356
# Epoch 22/100 - Loss:27.7985 Train Acc:96.90% Val Acc:92.92% Train F1:0.9690 Val F1:0.9291
# Epoch 23/100 - Loss:25.9840 Train Acc:97.40% Val Acc:92.41% Train F1:0.9740 Val F1:0.9239
# Epoch 24/100 - Loss:26.7009 Train Acc:97.06% Val Acc:92.19% Train F1:0.9706 Val F1:0.9217
# Epoch 25/100 - Loss:28.2183 Train Acc:97.15% Val Acc:93.87% Train F1:0.9715 Val F1:0.9386
# Epoch 26/100 - Loss:25.6944 Train Acc:97.40% Val Acc:90.88% Train F1:0.9740 Val F1:0.9083
# Epoch 27/100 - Loss:25.7283 Train Acc:97.34% Val Acc:93.65% Train F1:0.9734 Val F1:0.9365
# Epoch 28/100 - Loss:24.8332 Train Acc:97.68% Val Acc:78.18% Train F1:0.9768 Val F1:0.7769
# Epoch 29/100 - Loss:25.1617 Train Acc:97.25% Val Acc:93.07% Train F1:0.9725 Val F1:0.9306
# Epoch 30/100 - Loss:24.7639 Train Acc:98.03% Val Acc:83.28% Train F1:0.9803 Val F1:0.8285
# Epoch 31/100 - Loss:24.1997 Train Acc:97.68% Val Acc:51.82% Train F1:0.9768 Val F1:0.3738
# Epoch 32/100 - Loss:22.8974 Train Acc:98.31% Val Acc:94.45% Train F1:0.9831 Val F1:0.9445
# Epoch 33/100 - Loss:19.9648 Train Acc:98.62% Val Acc:51.61% Train F1:0.9862 Val F1:0.3692
# Epoch 34/100 - Loss:22.2679 Train Acc:98.15% Val Acc:84.09% Train F1:0.9815 Val F1:0.8403
# Epoch 35/100 - Loss:20.9335 Train Acc:98.47% Val Acc:51.39% Train F1:0.9847 Val F1:0.3681
# Epoch 36/100 - Loss:22.9667 Train Acc:97.90% Val Acc:50.07% Train F1:0.9790 Val F1:0.3375
# Epoch 37/100 - Loss:25.1490 Train Acc:96.90% Val Acc:82.92% Train F1:0.9690 Val F1:0.8249
# Epoch 38/100 - Loss:19.5817 Train Acc:98.69% Val Acc:93.65% Train F1:0.9869 Val F1:0.9364
# Epoch 39/100 - Loss:22.0244 Train Acc:97.56% Val Acc:93.80% Train F1:0.9756 Val F1:0.9380
# Epoch 40/100 - Loss:21.4680 Train Acc:97.93% Val Acc:70.36% Train F1:0.9793 Val F1:0.6806
# Epoch 41/100 - Loss:20.8029 Train Acc:98.31% Val Acc:90.66% Train F1:0.9831 Val F1:0.9065
# Epoch 42/100 - Loss:20.0022 Train Acc:98.50% Val Acc:94.01% Train F1:0.9850 Val F1:0.9401
# Epoch 43/100 - Loss:20.9176 Train Acc:98.34% Val Acc:93.28% Train F1:0.9834 Val F1:0.9328
# Epoch 44/100 - Loss:20.6183 Train Acc:97.87% Val Acc:80.73% Train F1:0.9787 Val F1:0.8073
# Epoch 45/100 - Loss:18.8739 Train Acc:98.56% Val Acc:51.68% Train F1:0.9856 Val F1:0.3707
# Epoch 46/100 - Loss:19.6860 Train Acc:98.44% Val Acc:90.88% Train F1:0.9844 Val F1:0.9083
# Epoch 47/100 - Loss:18.7653 Train Acc:98.65% Val Acc:78.32% Train F1:0.9865 Val F1:0.7745
# Epoch 48/100 - Loss:17.2768 Train Acc:98.75% Val Acc:93.87% Train F1:0.9875 Val F1:0.9386
# Epoch 49/100 - Loss:15.8851 Train Acc:99.12% Val Acc:94.16% Train F1:0.9912 Val F1:0.9416
# Epoch 50/100 - Loss:18.4460 Train Acc:98.62% Val Acc:88.54% Train F1:0.9862 Val F1:0.8841
# Epoch 51/100 - Loss:16.5815 Train Acc:99.28% Val Acc:82.19% Train F1:0.9928 Val F1:0.8209
# Epoch 52/100 - Loss:16.7592 Train Acc:98.97% Val Acc:57.81% Train F1:0.9897 Val F1:0.4935
# Epoch 53/100 - Loss:17.4860 Train Acc:98.31% Val Acc:94.09% Train F1:0.9831 Val F1:0.9409
# Epoch 54/100 - Loss:16.3320 Train Acc:99.16% Val Acc:85.11% Train F1:0.9916 Val F1:0.8489
# Epoch 55/100 - Loss:17.2719 Train Acc:98.75% Val Acc:69.49% Train F1:0.9875 Val F1:0.6665
# Epoch 56/100 - Loss:18.1590 Train Acc:98.94% Val Acc:93.87% Train F1:0.9894 Val F1:0.9387
# Epoch 57/100 - Loss:15.6807 Train Acc:99.28% Val Acc:94.31% Train F1:0.9928 Val F1:0.9431
# Epoch 58/100 - Loss:14.7978 Train Acc:99.37% Val Acc:94.67% Train F1:0.9937 Val F1:0.9467
# Epoch 59/100 - Loss:16.7470 Train Acc:98.90% Val Acc:88.10% Train F1:0.9890 Val F1:0.8810
# Epoch 60/100 - Loss:15.8305 Train Acc:99.09% Val Acc:86.64% Train F1:0.9909 Val F1:0.8644
# Epoch 61/100 - Loss:15.4104 Train Acc:99.19% Val Acc:93.28% Train F1:0.9919 Val F1:0.9327
# Epoch 62/100 - Loss:16.5349 Train Acc:98.87% Val Acc:93.07% Train F1:0.9887 Val F1:0.9307
# Epoch 63/100 - Loss:16.1740 Train Acc:98.84% Val Acc:88.03% Train F1:0.9884 Val F1:0.8796
# Epoch 64/100 - Loss:15.6585 Train Acc:99.25% Val Acc:92.99% Train F1:0.9925 Val F1:0.9299
# Epoch 65/100 - Loss:16.6077 Train Acc:98.81% Val Acc:92.70% Train F1:0.9881 Val F1:0.9270
# Epoch 66/100 - Loss:16.9960 Train Acc:98.75% Val Acc:90.73% Train F1:0.9875 Val F1:0.9069
# Epoch 67/100 - Loss:14.7000 Train Acc:99.12% Val Acc:94.23% Train F1:0.9912 Val F1:0.9423
# Epoch 68/100 - Loss:15.2430 Train Acc:99.16% Val Acc:50.22% Train F1:0.9916 Val F1:0.3445
# Epoch 69/100 - Loss:15.6248 Train Acc:99.31% Val Acc:90.36% Train F1:0.9931 Val F1:0.9033
# Epoch 70/100 - Loss:13.5216 Train Acc:99.22% Val Acc:70.51% Train F1:0.9922 Val F1:0.6788
# Epoch 71/100 - Loss:14.9929 Train Acc:99.37% Val Acc:90.00% Train F1:0.9937 Val F1:0.8995
# Epoch 72/100 - Loss:15.6533 Train Acc:98.87% Val Acc:85.33% Train F1:0.9887 Val F1:0.8510
# Epoch 73/100 - Loss:14.9416 Train Acc:99.19% Val Acc:76.20% Train F1:0.9919 Val F1:0.7532
# Epoch 74/100 - Loss:14.4223 Train Acc:98.94% Val Acc:93.80% Train F1:0.9894 Val F1:0.9379
# Epoch 75/100 - Loss:14.0487 Train Acc:99.25% Val Acc:94.31% Train F1:0.9925 Val F1:0.9430
# Epoch 76/100 - Loss:14.4455 Train Acc:99.25% Val Acc:93.58% Train F1:0.9925 Val F1:0.9358
# Epoch 77/100 - Loss:13.1553 Train Acc:99.44% Val Acc:70.07% Train F1:0.9944 Val F1:0.6734
# Epoch 78/100 - Loss:15.3681 Train Acc:99.19% Val Acc:93.07% Train F1:0.9919 Val F1:0.9306
# Epoch 79/100 - Loss:15.4440 Train Acc:99.28% Val Acc:57.81% Train F1:0.9928 Val F1:0.4977
# Epoch 80/100 - Loss:15.4159 Train Acc:99.06% Val Acc:94.23% Train F1:0.9906 Val F1:0.9423
# Epoch 81/100 - Loss:11.6395 Train Acc:99.72% Val Acc:82.70% Train F1:0.9972 Val F1:0.8230
# Epoch 82/100 - Loss:12.1632 Train Acc:99.62% Val Acc:92.12% Train F1:0.9962 Val F1:0.9211
# Epoch 83/100 - Loss:17.0237 Train Acc:98.78% Val Acc:92.92% Train F1:0.9878 Val F1:0.9291
# Epoch 84/100 - Loss:15.5148 Train Acc:98.84% Val Acc:93.28% Train F1:0.9884 Val F1:0.9327
# Epoch 85/100 - Loss:12.4536 Train Acc:99.59% Val Acc:93.14% Train F1:0.9959 Val F1:0.9313
# Epoch 86/100 - Loss:12.5068 Train Acc:99.72% Val Acc:87.15% Train F1:0.9972 Val F1:0.8708
# Epoch 87/100 - Loss:14.0974 Train Acc:98.97% Val Acc:83.58% Train F1:0.9897 Val F1:0.8332
# Epoch 88/100 - Loss:14.0591 Train Acc:99.12% Val Acc:87.66% Train F1:0.9912 Val F1:0.8760
# Epoch 89/100 - Loss:14.6184 Train Acc:99.37% Val Acc:93.87% Train F1:0.9937 Val F1:0.9387
# Epoch 90/100 - Loss:13.0906 Train Acc:99.50% Val Acc:51.97% Train F1:0.9950 Val F1:0.3791
# Epoch 91/100 - Loss:11.3665 Train Acc:99.75% Val Acc:91.02% Train F1:0.9975 Val F1:0.9098
# Epoch 92/100 - Loss:12.4628 Train Acc:99.47% Val Acc:87.59% Train F1:0.9947 Val F1:0.8755
# Epoch 93/100 - Loss:11.5726 Train Acc:99.75% Val Acc:91.61% Train F1:0.9975 Val F1:0.9157
# Epoch 94/100 - Loss:12.2929 Train Acc:99.41% Val Acc:92.48% Train F1:0.9941 Val F1:0.9246
# Epoch 95/100 - Loss:13.1632 Train Acc:99.12% Val Acc:93.58% Train F1:0.9912 Val F1:0.9357
# Epoch 96/100 - Loss:12.9802 Train Acc:99.47% Val Acc:58.91% Train F1:0.9947 Val F1:0.5097
# Epoch 97/100 - Loss:13.5567 Train Acc:99.31% Val Acc:94.16% Train F1:0.9931 Val F1:0.9416
# Epoch 98/100 - Loss:18.1886 Train Acc:98.87% Val Acc:91.82% Train F1:0.9887 Val F1:0.9182
# Epoch 99/100 - Loss:12.9080 Train Acc:99.16% Val Acc:67.37% Train F1:0.9916 Val F1:0.6360
# Epoch 100/100 - Loss:11.8223 Train Acc:99.50% Val Acc:92.55% Train F1:0.9950 Val F1:0.9255
# Training time: 0:01:58.086662
