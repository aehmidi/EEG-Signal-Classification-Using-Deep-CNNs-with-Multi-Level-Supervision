# %% [markdown]
# # ============================================================
# # EEG FEW-SHOT LEARNING FRAMEWORK
# # Sobel + Attention + KAN + Deep Supervision
# # ============================================================

# %% [markdown]
# # 🔷 ATTENTION MODULE
# **Attention1D(C, r=4)**

# %%
# ============================================================
# EEG FEW-SHOT LEARNING FRAMEWORK
# Sobel + Attention + KAN + Deep Supervision
# Train/Validation + ROC + PR + IEEE Figures
# ============================================================

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    auc,
    precision_recall_curve
)

# ============================================================
# DEVICE
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# LOAD DATA
# ============================================================

mat = sio.loadmat("SEED_VIG.mat")

X = mat["EEGsample"].astype(np.float32)
y = mat["substate"].squeeze()

X = (X - X.mean()) / (X.std() + 1e-6)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ============================================================
# DATASET
# ============================================================

class EEGDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_loader = DataLoader(EEGDataset(X_train, y_train), batch_size=32, shuffle=True)
val_loader   = DataLoader(EEGDataset(X_val, y_val), batch_size=32, shuffle=False)

# ============================================================
# SOBEL PROJECTION
# ============================================================

class Sobel1D(nn.Module):
    def __init__(self):
        super().__init__()
        k = torch.tensor([[[-1, 0, 1]]], dtype=torch.float32)
        self.weight = nn.Parameter(k, requires_grad=False)

    def forward(self, x):
        B, C, T = x.shape
        out = []
        for c in range(C):
            out.append(F.conv1d(x[:, c:c+1], self.weight, padding=1))
        return torch.cat(out, dim=1).abs()

# ============================================================
# ATTENTION
# ============================================================

class Attention1D(nn.Module):
    def __init__(self, C, r=4):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(C, C // r)
        self.fc2 = nn.Linear(C // r, C)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        B, C, T = x.shape
        y = self.pool(x).view(B, C)
        y = F.relu(self.fc1(y))
        y = self.sigmoid(self.fc2(y)).view(B, C, 1)
        return x * y

# ============================================================
# KAN MIXER
# ============================================================

class KAN(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.fc1 = nn.Linear(dim, dim * 2)
        self.fc2 = nn.Linear(dim * 2, dim)
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        r = x
        x = self.norm(x)
        x = F.gelu(self.fc1(x))
        x = self.fc2(x)
        return x + r

# ============================================================
# ENCODER
# ============================================================

class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.sobel = Sobel1D()

        self.conv1 = nn.Conv1d(17, 32, 5, padding=2)
        self.conv2 = nn.Conv1d(32, 64, 5, padding=2)
        self.conv3 = nn.Conv1d(64, 128, 5, padding=2)

        self.bn1 = nn.BatchNorm1d(32)
        self.bn2 = nn.BatchNorm1d(64)
        self.bn3 = nn.BatchNorm1d(128)

        self.att1 = Attention1D(32)
        self.att2 = Attention1D(64)
        self.att3 = Attention1D(128)

        self.pool = nn.MaxPool1d(2)

        self.kan = KAN(128)

        self.ds1 = nn.Linear(32, num_classes)
        self.ds2 = nn.Linear(64, num_classes)
        self.ds3 = nn.Linear(128, num_classes)

    def forward(self, x):

        x = x + self.sobel(x)

        x1 = self.pool(self.att1(F.relu(self.bn1(self.conv1(x)))))
        x2 = self.pool(self.att2(F.relu(self.bn2(self.conv2(x1)))))
        x3 = self.pool(self.att3(F.relu(self.bn3(self.conv3(x2)))))

        f1 = F.adaptive_avg_pool1d(x1, 1).squeeze(-1)
        f2 = F.adaptive_avg_pool1d(x2, 1).squeeze(-1)
        f3 = F.adaptive_avg_pool1d(x3, 1).squeeze(-1)

        f3 = self.kan(f3)

        return f3, self.ds1(f1), self.ds2(f2), self.ds3(f3)

# ============================================================
# MODEL
# ============================================================

num_classes = len(np.unique(y))

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.enc = Encoder(num_classes)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        f, d1, d2, d3 = self.enc(x)
        return self.fc(f), [d1, d2, d3]

model = Model().to(device)

# ============================================================
# LOSS + OPT
# ============================================================

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# ============================================================
# HISTORY
# ============================================================

history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": [],
    "train_f1": [],
    "val_f1": []
}

# ============================================================
# TRAINING
# ============================================================

start_time = datetime.now()
num_epochs = 100

for epoch in range(num_epochs):

    # ================= TRAIN =================
    model.train()
    train_p, train_y = [], []
    train_loss = 0

    for x, yb in train_loader:
        x, yb = x.to(device), yb.to(device)

        optimizer.zero_grad()

        logits, ds = model(x)

        loss = criterion(logits, yb)
        for d in ds:
            loss += 0.3 * criterion(d, yb)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        train_p.extend(torch.argmax(logits, 1).cpu().numpy())
        train_y.extend(yb.cpu().numpy())

    # ================= VAL =================
    model.eval()
    val_p, val_y = [], []
    val_loss = 0

    with torch.no_grad():
        for x, yb in val_loader:
            x, yb = x.to(device), yb.to(device)

            logits, _ = model(x)

            loss = criterion(logits, yb)
            val_loss += loss.item()

            val_p.extend(torch.argmax(logits, 1).cpu().numpy())
            val_y.extend(yb.cpu().numpy())

    # ================= METRICS =================
    tr_acc = accuracy_score(train_y, train_p) * 100
    va_acc = accuracy_score(val_y, val_p) * 100

    tr_f1 = f1_score(train_y, train_p, average='weighted')
    va_f1 = f1_score(val_y, val_p, average='weighted')

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(va_acc)
    history["train_f1"].append(tr_f1)
    history["val_f1"].append(va_f1)

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Loss:{train_loss:.4f} "
          f"Train Acc:{tr_acc:.2f}% "
          f"Val Acc:{va_acc:.2f}% "
          f"Train F1:{tr_f1:.4f} "
          f"Val F1:{va_f1:.4f}")

print("Training time:", datetime.now() - start_time)

# ============================================================
# VISUALIZATION (BLUE=VAL, ORANGE=TRAIN)
# ============================================================

epochs = range(num_epochs)

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

# LOSS
ax[0,0].plot(history["train_loss"], color='orange')
ax[0,0].plot(history["val_loss"], color='blue')
ax[0,0].set_title("Loss")

# ACC
ax[0,1].plot(history["train_acc"], color='orange')
ax[0,1].plot(history["val_acc"], color='blue')
ax[0,1].set_title("Accuracy")

# F1
ax[0,2].plot(history["train_f1"], color='orange')
ax[0,2].plot(history["val_f1"], color='blue')
ax[0,2].set_title("F1-score")

plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Epoch 1/100 - Loss:87.8718 Train Acc:82.63% Val Acc:89.42% Train F1:0.8263 Val F1:0.8940
# Epoch 2/100 - Loss:71.5621 Train Acc:88.49% Val Acc:91.90% Train F1:0.8848 Val F1:0.9188
# Epoch 3/100 - Loss:59.4077 Train Acc:91.33% Val Acc:90.15% Train F1:0.9133 Val F1:0.9010
# Epoch 4/100 - Loss:58.8086 Train Acc:91.15% Val Acc:90.73% Train F1:0.9114 Val F1:0.9070
# Epoch 5/100 - Loss:51.1647 Train Acc:92.46% Val Acc:55.26% Train F1:0.9246 Val F1:0.4433
# Epoch 6/100 - Loss:47.8466 Train Acc:93.09% Val Acc:89.42% Train F1:0.9308 Val F1:0.8938
# Epoch 7/100 - Loss:48.3353 Train Acc:93.05% Val Acc:87.37% Train F1:0.9305 Val F1:0.8737
# Epoch 8/100 - Loss:43.1897 Train Acc:93.30% Val Acc:89.64% Train F1:0.9330 Val F1:0.8956
# Epoch 9/100 - Loss:42.8964 Train Acc:93.65% Val Acc:88.03% Train F1:0.9365 Val F1:0.8800
# Epoch 10/100 - Loss:42.1540 Train Acc:93.59% Val Acc:76.86% Train F1:0.9358 Val F1:0.7569
# Epoch 11/100 - Loss:38.6969 Train Acc:94.71% Val Acc:92.04% Train F1:0.9471 Val F1:0.9204
# Epoch 12/100 - Loss:39.1514 Train Acc:94.59% Val Acc:83.21% Train F1:0.9458 Val F1:0.8289
# Epoch 13/100 - Loss:36.6960 Train Acc:95.12% Val Acc:92.85% Train F1:0.9512 Val F1:0.9284
# Epoch 14/100 - Loss:35.1589 Train Acc:95.37% Val Acc:93.94% Train F1:0.9537 Val F1:0.9394
# Epoch 15/100 - Loss:32.6551 Train Acc:95.99% Val Acc:93.14% Train F1:0.9599 Val F1:0.9313
# Epoch 16/100 - Loss:30.3649 Train Acc:96.21% Val Acc:52.77% Train F1:0.9621 Val F1:0.3932
# Epoch 17/100 - Loss:31.3693 Train Acc:95.96% Val Acc:77.81% Train F1:0.9596 Val F1:0.7669
# Epoch 18/100 - Loss:30.7001 Train Acc:96.03% Val Acc:93.58% Train F1:0.9603 Val F1:0.9358
# Epoch 19/100 - Loss:30.4471 Train Acc:96.21% Val Acc:80.51% Train F1:0.9621 Val F1:0.7989
# Epoch 20/100 - Loss:27.7747 Train Acc:96.50% Val Acc:93.50% Train F1:0.9650 Val F1:0.9350
# Epoch 21/100 - Loss:27.5860 Train Acc:96.90% Val Acc:85.55% Train F1:0.9690 Val F1:0.8529
# Epoch 22/100 - Loss:26.3121 Train Acc:97.22% Val Acc:64.45% Train F1:0.9722 Val F1:0.6000
# Epoch 23/100 - Loss:26.5968 Train Acc:96.96% Val Acc:92.04% Train F1:0.9696 Val F1:0.9204
# Epoch 24/100 - Loss:23.8292 Train Acc:97.56% Val Acc:92.55% Train F1:0.9756 Val F1:0.9254
# Epoch 25/100 - Loss:24.7822 Train Acc:97.18% Val Acc:72.63% Train F1:0.9718 Val F1:0.7063
# Epoch 26/100 - Loss:24.4219 Train Acc:97.47% Val Acc:88.76% Train F1:0.9747 Val F1:0.8870
# Epoch 27/100 - Loss:22.2061 Train Acc:97.81% Val Acc:93.50% Train F1:0.9781 Val F1:0.9349
# Epoch 28/100 - Loss:21.8448 Train Acc:97.87% Val Acc:92.48% Train F1:0.9787 Val F1:0.9246
# Epoch 29/100 - Loss:22.1219 Train Acc:97.84% Val Acc:52.85% Train F1:0.9784 Val F1:0.4010
# Epoch 30/100 - Loss:25.5027 Train Acc:96.65% Val Acc:67.15% Train F1:0.9665 Val F1:0.6360
# Epoch 31/100 - Loss:24.0687 Train Acc:97.25% Val Acc:90.29% Train F1:0.9725 Val F1:0.9029
# Epoch 32/100 - Loss:21.1957 Train Acc:98.22% Val Acc:80.22% Train F1:0.9822 Val F1:0.8013
# Epoch 33/100 - Loss:22.3697 Train Acc:97.93% Val Acc:92.12% Train F1:0.9793 Val F1:0.9211
# Epoch 34/100 - Loss:20.9182 Train Acc:98.09% Val Acc:76.86% Train F1:0.9809 Val F1:0.7586
# Epoch 35/100 - Loss:21.8945 Train Acc:97.90% Val Acc:62.41% Train F1:0.9790 Val F1:0.5697
# Epoch 36/100 - Loss:20.4767 Train Acc:97.93% Val Acc:87.88% Train F1:0.9793 Val F1:0.8778
# Epoch 37/100 - Loss:22.0581 Train Acc:98.00% Val Acc:51.24% Train F1:0.9800 Val F1:0.3615
# Epoch 38/100 - Loss:21.4392 Train Acc:97.90% Val Acc:74.16% Train F1:0.9790 Val F1:0.7341
# Epoch 39/100 - Loss:17.6724 Train Acc:98.44% Val Acc:60.44% Train F1:0.9844 Val F1:0.5335
# Epoch 40/100 - Loss:15.9278 Train Acc:98.94% Val Acc:50.88% Train F1:0.9894 Val F1:0.3585
# Epoch 41/100 - Loss:18.6412 Train Acc:98.40% Val Acc:87.15% Train F1:0.9840 Val F1:0.8701
# Epoch 42/100 - Loss:17.3394 Train Acc:98.94% Val Acc:81.90% Train F1:0.9894 Val F1:0.8163
# Epoch 43/100 - Loss:17.3460 Train Acc:98.69% Val Acc:51.68% Train F1:0.9869 Val F1:0.3719
# Epoch 44/100 - Loss:18.6575 Train Acc:98.50% Val Acc:52.63% Train F1:0.9850 Val F1:0.3967
# Epoch 45/100 - Loss:17.2879 Train Acc:98.90% Val Acc:83.50% Train F1:0.9890 Val F1:0.8314
# Epoch 46/100 - Loss:15.2163 Train Acc:99.34% Val Acc:76.79% Train F1:0.9934 Val F1:0.7581
# Epoch 47/100 - Loss:18.4879 Train Acc:98.44% Val Acc:62.26% Train F1:0.9844 Val F1:0.5633
# Epoch 48/100 - Loss:16.0035 Train Acc:99.37% Val Acc:86.42% Train F1:0.9937 Val F1:0.8634
# Epoch 49/100 - Loss:20.0190 Train Acc:97.97% Val Acc:53.21% Train F1:0.9797 Val F1:0.4041
# Epoch 50/100 - Loss:17.8647 Train Acc:98.47% Val Acc:87.66% Train F1:0.9847 Val F1:0.8757
# Epoch 51/100 - Loss:16.8398 Train Acc:98.87% Val Acc:93.65% Train F1:0.9887 Val F1:0.9364
# Epoch 52/100 - Loss:16.5081 Train Acc:98.84% Val Acc:52.92% Train F1:0.9884 Val F1:0.3962
# Epoch 53/100 - Loss:16.5339 Train Acc:99.16% Val Acc:89.56% Train F1:0.9916 Val F1:0.8949
# Epoch 54/100 - Loss:15.3760 Train Acc:99.06% Val Acc:94.53% Train F1:0.9906 Val F1:0.9452
# Epoch 55/100 - Loss:15.9535 Train Acc:98.78% Val Acc:93.21% Train F1:0.9878 Val F1:0.9321
# Epoch 56/100 - Loss:15.5770 Train Acc:98.94% Val Acc:66.57% Train F1:0.9894 Val F1:0.6481
# Epoch 57/100 - Loss:16.2267 Train Acc:98.94% Val Acc:88.98% Train F1:0.9894 Val F1:0.8895
# Epoch 58/100 - Loss:16.9175 Train Acc:98.47% Val Acc:82.12% Train F1:0.9847 Val F1:0.8208
# Epoch 59/100 - Loss:17.2462 Train Acc:98.34% Val Acc:87.66% Train F1:0.9834 Val F1:0.8751
# Epoch 60/100 - Loss:16.7412 Train Acc:98.37% Val Acc:81.75% Train F1:0.9837 Val F1:0.8137
# Epoch 61/100 - Loss:13.6869 Train Acc:99.19% Val Acc:94.09% Train F1:0.9919 Val F1:0.9408
# Epoch 62/100 - Loss:14.8465 Train Acc:98.94% Val Acc:94.16% Train F1:0.9894 Val F1:0.9416
# Epoch 63/100 - Loss:16.6340 Train Acc:98.44% Val Acc:93.72% Train F1:0.9844 Val F1:0.9371
# Epoch 64/100 - Loss:15.3992 Train Acc:98.87% Val Acc:62.63% Train F1:0.9887 Val F1:0.5750
# Epoch 65/100 - Loss:15.0518 Train Acc:99.09% Val Acc:65.04% Train F1:0.9909 Val F1:0.6026
# Epoch 66/100 - Loss:14.9621 Train Acc:98.97% Val Acc:79.71% Train F1:0.9897 Val F1:0.7922
# Epoch 67/100 - Loss:16.1465 Train Acc:98.78% Val Acc:88.98% Train F1:0.9878 Val F1:0.8889
# Epoch 68/100 - Loss:14.2660 Train Acc:98.97% Val Acc:94.01% Train F1:0.9897 Val F1:0.9401
# Epoch 69/100 - Loss:17.4566 Train Acc:98.65% Val Acc:91.46% Train F1:0.9865 Val F1:0.9145
# Epoch 70/100 - Loss:14.8289 Train Acc:99.25% Val Acc:94.16% Train F1:0.9925 Val F1:0.9415
# Epoch 71/100 - Loss:12.8276 Train Acc:99.56% Val Acc:87.66% Train F1:0.9956 Val F1:0.8753
# Epoch 72/100 - Loss:13.2057 Train Acc:99.47% Val Acc:77.45% Train F1:0.9947 Val F1:0.7639
# Epoch 73/100 - Loss:14.3173 Train Acc:99.31% Val Acc:93.58% Train F1:0.9931 Val F1:0.9357
# Epoch 74/100 - Loss:12.4276 Train Acc:99.66% Val Acc:76.35% Train F1:0.9966 Val F1:0.7519
# Epoch 75/100 - Loss:13.5885 Train Acc:99.28% Val Acc:92.48% Train F1:0.9928 Val F1:0.9246
# Epoch 76/100 - Loss:14.0162 Train Acc:99.16% Val Acc:93.50% Train F1:0.9916 Val F1:0.9349
# Epoch 77/100 - Loss:12.8396 Train Acc:99.47% Val Acc:88.98% Train F1:0.9947 Val F1:0.8890
# Epoch 78/100 - Loss:15.4378 Train Acc:98.97% Val Acc:91.75% Train F1:0.9897 Val F1:0.9172
# Epoch 79/100 - Loss:12.6255 Train Acc:99.59% Val Acc:92.48% Train F1:0.9959 Val F1:0.9246
# Epoch 80/100 - Loss:14.1101 Train Acc:99.09% Val Acc:92.48% Train F1:0.9909 Val F1:0.9248
# Epoch 81/100 - Loss:13.7803 Train Acc:99.22% Val Acc:59.56% Train F1:0.9922 Val F1:0.5457
# Epoch 82/100 - Loss:11.0203 Train Acc:99.81% Val Acc:90.07% Train F1:0.9981 Val F1:0.9002
# Epoch 83/100 - Loss:14.2408 Train Acc:99.19% Val Acc:92.41% Train F1:0.9919 Val F1:0.9238
# Epoch 84/100 - Loss:13.1530 Train Acc:99.37% Val Acc:94.23% Train F1:0.9937 Val F1:0.9423
# Epoch 85/100 - Loss:15.6446 Train Acc:98.78% Val Acc:86.42% Train F1:0.9878 Val F1:0.8634
# Epoch 86/100 - Loss:13.6488 Train Acc:99.44% Val Acc:59.34% Train F1:0.9944 Val F1:0.5241
# Epoch 87/100 - Loss:13.1019 Train Acc:99.47% Val Acc:94.31% Train F1:0.9947 Val F1:0.9430
# Epoch 88/100 - Loss:12.6181 Train Acc:99.31% Val Acc:92.19% Train F1:0.9931 Val F1:0.9217
# Epoch 89/100 - Loss:12.5999 Train Acc:99.37% Val Acc:58.25% Train F1:0.9937 Val F1:0.4973
# Epoch 90/100 - Loss:12.6082 Train Acc:99.62% Val Acc:80.15% Train F1:0.9962 Val F1:0.7962
# Epoch 91/100 - Loss:13.6935 Train Acc:99.19% Val Acc:93.43% Train F1:0.9919 Val F1:0.9342
# Epoch 92/100 - Loss:12.3485 Train Acc:99.56% Val Acc:68.39% Train F1:0.9956 Val F1:0.6670
# Epoch 93/100 - Loss:12.1933 Train Acc:99.56% Val Acc:89.93% Train F1:0.9956 Val F1:0.8989
# Epoch 94/100 - Loss:12.3801 Train Acc:99.59% Val Acc:57.30% Train F1:0.9959 Val F1:0.4801
# Epoch 95/100 - Loss:12.5682 Train Acc:99.41% Val Acc:54.74% Train F1:0.9941 Val F1:0.4328
# Epoch 96/100 - Loss:13.6037 Train Acc:99.19% Val Acc:92.63% Train F1:0.9919 Val F1:0.9262
# Epoch 97/100 - Loss:12.4319 Train Acc:99.44% Val Acc:75.40% Train F1:0.9944 Val F1:0.7406
# Epoch 98/100 - Loss:11.2091 Train Acc:99.69% Val Acc:94.38% Train F1:0.9969 Val F1:0.9438
# Epoch 99/100 - Loss:11.7047 Train Acc:99.62% Val Acc:89.05% Train F1:0.9962 Val F1:0.8897
# Epoch 100/100 - Loss:13.8199 Train Acc:99.28% Val Acc:52.41% Train F1:0.9928 Val F1:0.3891
# Training time: 0:02:15.960249

# %% [markdown]
# **Attention1D(C, r=16)**

# %%
# ============================================================
# EEG FEW-SHOT LEARNING FRAMEWORK
# Sobel + Attention + KAN + Deep Supervision
# Train/Validation + ROC + PR + IEEE Figures
# ============================================================

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    auc,
    precision_recall_curve
)

# ============================================================
# DEVICE
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# LOAD DATA
# ============================================================

mat = sio.loadmat("SEED_VIG.mat")

X = mat["EEGsample"].astype(np.float32)
y = mat["substate"].squeeze()

X = (X - X.mean()) / (X.std() + 1e-6)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ============================================================
# DATASET
# ============================================================

class EEGDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_loader = DataLoader(EEGDataset(X_train, y_train), batch_size=32, shuffle=True)
val_loader   = DataLoader(EEGDataset(X_val, y_val), batch_size=32, shuffle=False)

# ============================================================
# SOBEL PROJECTION
# ============================================================

class Sobel1D(nn.Module):
    def __init__(self):
        super().__init__()
        k = torch.tensor([[[-1, 0, 1]]], dtype=torch.float32)
        self.weight = nn.Parameter(k, requires_grad=False)

    def forward(self, x):
        B, C, T = x.shape
        out = []
        for c in range(C):
            out.append(F.conv1d(x[:, c:c+1], self.weight, padding=1))
        return torch.cat(out, dim=1).abs()

# ============================================================
# ATTENTION
# ============================================================

class Attention1D(nn.Module):
    def __init__(self, C, r=16):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(C, C // r)
        self.fc2 = nn.Linear(C // r, C)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        B, C, T = x.shape
        y = self.pool(x).view(B, C)
        y = F.relu(self.fc1(y))
        y = self.sigmoid(self.fc2(y)).view(B, C, 1)
        return x * y

# ============================================================
# KAN MIXER
# ============================================================

class KAN(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.fc1 = nn.Linear(dim, dim * 2)
        self.fc2 = nn.Linear(dim * 2, dim)
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        r = x
        x = self.norm(x)
        x = F.gelu(self.fc1(x))
        x = self.fc2(x)
        return x + r

# ============================================================
# ENCODER
# ============================================================

class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.sobel = Sobel1D()

        self.conv1 = nn.Conv1d(17, 32, 5, padding=2)
        self.conv2 = nn.Conv1d(32, 64, 5, padding=2)
        self.conv3 = nn.Conv1d(64, 128, 5, padding=2)

        self.bn1 = nn.BatchNorm1d(32)
        self.bn2 = nn.BatchNorm1d(64)
        self.bn3 = nn.BatchNorm1d(128)

        self.att1 = Attention1D(32)
        self.att2 = Attention1D(64)
        self.att3 = Attention1D(128)

        self.pool = nn.MaxPool1d(2)

        self.kan = KAN(128)

        self.ds1 = nn.Linear(32, num_classes)
        self.ds2 = nn.Linear(64, num_classes)
        self.ds3 = nn.Linear(128, num_classes)

    def forward(self, x):

        x = x + self.sobel(x)

        x1 = self.pool(self.att1(F.relu(self.bn1(self.conv1(x)))))
        x2 = self.pool(self.att2(F.relu(self.bn2(self.conv2(x1)))))
        x3 = self.pool(self.att3(F.relu(self.bn3(self.conv3(x2)))))

        f1 = F.adaptive_avg_pool1d(x1, 1).squeeze(-1)
        f2 = F.adaptive_avg_pool1d(x2, 1).squeeze(-1)
        f3 = F.adaptive_avg_pool1d(x3, 1).squeeze(-1)

        f3 = self.kan(f3)

        return f3, self.ds1(f1), self.ds2(f2), self.ds3(f3)

# ============================================================
# MODEL
# ============================================================

num_classes = len(np.unique(y))

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.enc = Encoder(num_classes)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        f, d1, d2, d3 = self.enc(x)
        return self.fc(f), [d1, d2, d3]

model = Model().to(device)

# ============================================================
# LOSS + OPT
# ============================================================

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# ============================================================
# HISTORY
# ============================================================

history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": [],
    "train_f1": [],
    "val_f1": []
}

# ============================================================
# TRAINING
# ============================================================

start_time = datetime.now()
num_epochs = 100

for epoch in range(num_epochs):

    # ================= TRAIN =================
    model.train()
    train_p, train_y = [], []
    train_loss = 0

    for x, yb in train_loader:
        x, yb = x.to(device), yb.to(device)

        optimizer.zero_grad()

        logits, ds = model(x)

        loss = criterion(logits, yb)
        for d in ds:
            loss += 0.3 * criterion(d, yb)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        train_p.extend(torch.argmax(logits, 1).cpu().numpy())
        train_y.extend(yb.cpu().numpy())

    # ================= VAL =================
    model.eval()
    val_p, val_y = [], []
    val_loss = 0

    with torch.no_grad():
        for x, yb in val_loader:
            x, yb = x.to(device), yb.to(device)

            logits, _ = model(x)

            loss = criterion(logits, yb)
            val_loss += loss.item()

            val_p.extend(torch.argmax(logits, 1).cpu().numpy())
            val_y.extend(yb.cpu().numpy())

    # ================= METRICS =================
    tr_acc = accuracy_score(train_y, train_p) * 100
    va_acc = accuracy_score(val_y, val_p) * 100

    tr_f1 = f1_score(train_y, train_p, average='weighted')
    va_f1 = f1_score(val_y, val_p, average='weighted')

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(va_acc)
    history["train_f1"].append(tr_f1)
    history["val_f1"].append(va_f1)

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Loss:{train_loss:.4f} "
          f"Train Acc:{tr_acc:.2f}% "
          f"Val Acc:{va_acc:.2f}% "
          f"Train F1:{tr_f1:.4f} "
          f"Val F1:{va_f1:.4f}")

print("Training time:", datetime.now() - start_time)

# ============================================================
# VISUALIZATION (BLUE=VAL, ORANGE=TRAIN)
# ============================================================

epochs = range(num_epochs)

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

# LOSS
ax[0,0].plot(history["train_loss"], color='orange')
ax[0,0].plot(history["val_loss"], color='blue')
ax[0,0].set_title("Loss")

# ACC
ax[0,1].plot(history["train_acc"], color='orange')
ax[0,1].plot(history["val_acc"], color='blue')
ax[0,1].set_title("Accuracy")

# F1
ax[0,2].plot(history["train_f1"], color='orange')
ax[0,2].plot(history["val_f1"], color='blue')
ax[0,2].set_title("F1-score")

plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Epoch 1/100 - Loss:89.2312 Train Acc:82.20% Val Acc:73.58% Train F1:0.8220 Val F1:0.7182
# Epoch 2/100 - Loss:70.3608 Train Acc:88.27% Val Acc:91.02% Train F1:0.8826 Val F1:0.9102
# Epoch 3/100 - Loss:60.2208 Train Acc:91.18% Val Acc:86.42% Train F1:0.9118 Val F1:0.8636
# Epoch 4/100 - Loss:54.6821 Train Acc:91.65% Val Acc:91.82% Train F1:0.9165 Val F1:0.9180
# Epoch 5/100 - Loss:51.7722 Train Acc:92.27% Val Acc:89.71% Train F1:0.9227 Val F1:0.8971
# Epoch 6/100 - Loss:49.5970 Train Acc:93.05% Val Acc:91.46% Train F1:0.9305 Val F1:0.9146
# Epoch 7/100 - Loss:45.2045 Train Acc:93.87% Val Acc:88.03% Train F1:0.9387 Val F1:0.8790
# Epoch 8/100 - Loss:42.2132 Train Acc:94.34% Val Acc:84.45% Train F1:0.9434 Val F1:0.8417
# Epoch 9/100 - Loss:43.0914 Train Acc:93.52% Val Acc:87.88% Train F1:0.9352 Val F1:0.8778
# Epoch 10/100 - Loss:41.6916 Train Acc:93.65% Val Acc:89.49% Train F1:0.9365 Val F1:0.8940
# Epoch 11/100 - Loss:37.7169 Train Acc:95.15% Val Acc:51.09% Train F1:0.9515 Val F1:0.3584
# Epoch 12/100 - Loss:36.5961 Train Acc:95.31% Val Acc:85.40% Train F1:0.9531 Val F1:0.8516
# Epoch 13/100 - Loss:36.5539 Train Acc:95.37% Val Acc:89.85% Train F1:0.9537 Val F1:0.8977
# Epoch 14/100 - Loss:33.8257 Train Acc:95.65% Val Acc:59.56% Train F1:0.9565 Val F1:0.5206
# Epoch 15/100 - Loss:34.7003 Train Acc:95.21% Val Acc:79.56% Train F1:0.9521 Val F1:0.7885
# Epoch 16/100 - Loss:35.0099 Train Acc:95.12% Val Acc:92.04% Train F1:0.9512 Val F1:0.9202
# Epoch 17/100 - Loss:31.5582 Train Acc:96.40% Val Acc:92.04% Train F1:0.9640 Val F1:0.9203
# Epoch 18/100 - Loss:33.5563 Train Acc:95.81% Val Acc:86.86% Train F1:0.9581 Val F1:0.8670
# Epoch 19/100 - Loss:31.6779 Train Acc:95.81% Val Acc:88.69% Train F1:0.9581 Val F1:0.8858
# Epoch 20/100 - Loss:30.2535 Train Acc:96.31% Val Acc:90.29% Train F1:0.9631 Val F1:0.9029
# Epoch 21/100 - Loss:29.3172 Train Acc:96.56% Val Acc:84.45% Train F1:0.9656 Val F1:0.8440
# Epoch 22/100 - Loss:29.8501 Train Acc:96.31% Val Acc:82.92% Train F1:0.9631 Val F1:0.8248
# Epoch 23/100 - Loss:27.7708 Train Acc:96.56% Val Acc:88.47% Train F1:0.9656 Val F1:0.8839
# Epoch 24/100 - Loss:28.7436 Train Acc:96.71% Val Acc:87.45% Train F1:0.9671 Val F1:0.8740
# Epoch 25/100 - Loss:26.4250 Train Acc:97.25% Val Acc:85.11% Train F1:0.9725 Val F1:0.8490
# Epoch 26/100 - Loss:26.7203 Train Acc:96.93% Val Acc:87.37% Train F1:0.9693 Val F1:0.8724
# Epoch 27/100 - Loss:28.6066 Train Acc:96.12% Val Acc:94.31% Train F1:0.9612 Val F1:0.9430
# Epoch 28/100 - Loss:27.5311 Train Acc:96.65% Val Acc:64.01% Train F1:0.9665 Val F1:0.5886
# Epoch 29/100 - Loss:24.4306 Train Acc:97.43% Val Acc:85.18% Train F1:0.9743 Val F1:0.8494
# Epoch 30/100 - Loss:26.0717 Train Acc:96.96% Val Acc:83.43% Train F1:0.9696 Val F1:0.8308
# Epoch 31/100 - Loss:24.9506 Train Acc:97.37% Val Acc:94.96% Train F1:0.9737 Val F1:0.9496
# Epoch 32/100 - Loss:25.4576 Train Acc:96.96% Val Acc:92.70% Train F1:0.9696 Val F1:0.9270
# Epoch 33/100 - Loss:24.2576 Train Acc:97.31% Val Acc:67.52% Train F1:0.9731 Val F1:0.6434
# Epoch 34/100 - Loss:23.0664 Train Acc:97.81% Val Acc:89.71% Train F1:0.9781 Val F1:0.8962
# Epoch 35/100 - Loss:21.4696 Train Acc:98.22% Val Acc:77.15% Train F1:0.9822 Val F1:0.7628
# Epoch 36/100 - Loss:22.7714 Train Acc:97.87% Val Acc:93.07% Train F1:0.9787 Val F1:0.9306
# Epoch 37/100 - Loss:20.4785 Train Acc:98.31% Val Acc:56.93% Train F1:0.9831 Val F1:0.4837
# Epoch 38/100 - Loss:20.7924 Train Acc:98.31% Val Acc:92.34% Train F1:0.9831 Val F1:0.9233
# Epoch 39/100 - Loss:22.3069 Train Acc:97.50% Val Acc:82.77% Train F1:0.9750 Val F1:0.8252
# Epoch 40/100 - Loss:21.2242 Train Acc:98.03% Val Acc:92.99% Train F1:0.9803 Val F1:0.9299
# Epoch 41/100 - Loss:21.8752 Train Acc:97.93% Val Acc:56.72% Train F1:0.9793 Val F1:0.4746
# Epoch 42/100 - Loss:19.9199 Train Acc:98.34% Val Acc:77.15% Train F1:0.9834 Val F1:0.7678
# Epoch 43/100 - Loss:20.4630 Train Acc:98.37% Val Acc:84.53% Train F1:0.9837 Val F1:0.8431
# Epoch 44/100 - Loss:21.2448 Train Acc:97.90% Val Acc:68.25% Train F1:0.9790 Val F1:0.6715
# Epoch 45/100 - Loss:18.2220 Train Acc:98.53% Val Acc:92.48% Train F1:0.9853 Val F1:0.9246
# Epoch 46/100 - Loss:18.7919 Train Acc:98.50% Val Acc:73.21% Train F1:0.9850 Val F1:0.7187
# Epoch 47/100 - Loss:18.7943 Train Acc:98.62% Val Acc:92.26% Train F1:0.9862 Val F1:0.9224
# Epoch 48/100 - Loss:21.5790 Train Acc:98.19% Val Acc:89.93% Train F1:0.9819 Val F1:0.8987
# Epoch 49/100 - Loss:19.5657 Train Acc:98.72% Val Acc:92.48% Train F1:0.9872 Val F1:0.9247
# Epoch 50/100 - Loss:18.6025 Train Acc:98.62% Val Acc:54.82% Train F1:0.9862 Val F1:0.4378
# Epoch 51/100 - Loss:19.7108 Train Acc:98.15% Val Acc:66.86% Train F1:0.9815 Val F1:0.6320
# Epoch 52/100 - Loss:16.5974 Train Acc:98.94% Val Acc:85.91% Train F1:0.9894 Val F1:0.8569
# Epoch 53/100 - Loss:20.6282 Train Acc:97.97% Val Acc:88.76% Train F1:0.9797 Val F1:0.8869
# Epoch 54/100 - Loss:17.3689 Train Acc:99.06% Val Acc:51.09% Train F1:0.9906 Val F1:0.3608
# Epoch 55/100 - Loss:16.2742 Train Acc:98.94% Val Acc:78.39% Train F1:0.9894 Val F1:0.7745
# Epoch 56/100 - Loss:16.5412 Train Acc:99.09% Val Acc:50.51% Train F1:0.9909 Val F1:0.3458
# Epoch 57/100 - Loss:18.8497 Train Acc:98.47% Val Acc:92.34% Train F1:0.9847 Val F1:0.9232
# Epoch 58/100 - Loss:15.6871 Train Acc:99.09% Val Acc:91.02% Train F1:0.9909 Val F1:0.9101
# Epoch 59/100 - Loss:18.0388 Train Acc:98.75% Val Acc:93.87% Train F1:0.9875 Val F1:0.9387
# Epoch 60/100 - Loss:18.2270 Train Acc:98.53% Val Acc:90.44% Train F1:0.9853 Val F1:0.9039
# Epoch 61/100 - Loss:16.4638 Train Acc:98.81% Val Acc:72.04% Train F1:0.9881 Val F1:0.7017
# Epoch 62/100 - Loss:15.3997 Train Acc:99.03% Val Acc:60.80% Train F1:0.9903 Val F1:0.5424
# Epoch 63/100 - Loss:18.3614 Train Acc:98.65% Val Acc:74.45% Train F1:0.9865 Val F1:0.7444
# Epoch 64/100 - Loss:15.3744 Train Acc:99.19% Val Acc:61.09% Train F1:0.9919 Val F1:0.5678
# Epoch 65/100 - Loss:17.6809 Train Acc:98.50% Val Acc:87.37% Train F1:0.9850 Val F1:0.8724
# Epoch 66/100 - Loss:16.0424 Train Acc:98.78% Val Acc:92.63% Train F1:0.9878 Val F1:0.9262
# Epoch 67/100 - Loss:17.6980 Train Acc:98.56% Val Acc:83.80% Train F1:0.9856 Val F1:0.8347
# Epoch 68/100 - Loss:14.1517 Train Acc:99.28% Val Acc:87.23% Train F1:0.9928 Val F1:0.8708
# Epoch 69/100 - Loss:16.2554 Train Acc:98.84% Val Acc:89.27% Train F1:0.9884 Val F1:0.8919
# Epoch 70/100 - Loss:15.4192 Train Acc:99.09% Val Acc:91.82% Train F1:0.9909 Val F1:0.9179
# Epoch 71/100 - Loss:17.9686 Train Acc:98.65% Val Acc:90.44% Train F1:0.9865 Val F1:0.9041
# Epoch 72/100 - Loss:15.2379 Train Acc:99.19% Val Acc:67.23% Train F1:0.9919 Val F1:0.6392
# Epoch 73/100 - Loss:14.0720 Train Acc:99.34% Val Acc:93.58% Train F1:0.9934 Val F1:0.9357
# Epoch 74/100 - Loss:13.9869 Train Acc:99.44% Val Acc:91.90% Train F1:0.9944 Val F1:0.9188
# Epoch 75/100 - Loss:14.7274 Train Acc:99.25% Val Acc:76.72% Train F1:0.9925 Val F1:0.7563
# Epoch 76/100 - Loss:16.3278 Train Acc:98.75% Val Acc:61.75% Train F1:0.9875 Val F1:0.5577
# Epoch 77/100 - Loss:14.1905 Train Acc:99.22% Val Acc:85.04% Train F1:0.9922 Val F1:0.8479
# Epoch 78/100 - Loss:15.4337 Train Acc:98.84% Val Acc:73.36% Train F1:0.9884 Val F1:0.7183
# Epoch 79/100 - Loss:13.2305 Train Acc:99.12% Val Acc:93.72% Train F1:0.9912 Val F1:0.9372
# Epoch 80/100 - Loss:17.1363 Train Acc:98.50% Val Acc:55.40% Train F1:0.9850 Val F1:0.4486
# Epoch 81/100 - Loss:13.5751 Train Acc:99.25% Val Acc:90.66% Train F1:0.9925 Val F1:0.9062
# Epoch 82/100 - Loss:15.5703 Train Acc:98.75% Val Acc:77.96% Train F1:0.9875 Val F1:0.7698
# Epoch 83/100 - Loss:15.6376 Train Acc:99.12% Val Acc:61.46% Train F1:0.9912 Val F1:0.5565
# Epoch 84/100 - Loss:13.1044 Train Acc:99.53% Val Acc:88.98% Train F1:0.9953 Val F1:0.8888
# Epoch 85/100 - Loss:14.6153 Train Acc:99.25% Val Acc:54.31% Train F1:0.9925 Val F1:0.4273
# Epoch 86/100 - Loss:15.2977 Train Acc:99.25% Val Acc:87.37% Train F1:0.9925 Val F1:0.8723
# Epoch 87/100 - Loss:13.2302 Train Acc:99.22% Val Acc:93.28% Train F1:0.9922 Val F1:0.9328
# Epoch 88/100 - Loss:13.3629 Train Acc:99.66% Val Acc:69.20% Train F1:0.9966 Val F1:0.6613
# Epoch 89/100 - Loss:12.3036 Train Acc:99.41% Val Acc:61.09% Train F1:0.9941 Val F1:0.5446
# Epoch 90/100 - Loss:15.5600 Train Acc:98.84% Val Acc:52.48% Train F1:0.9884 Val F1:0.3884
# Epoch 91/100 - Loss:12.1637 Train Acc:99.59% Val Acc:56.57% Train F1:0.9959 Val F1:0.4656
# Epoch 92/100 - Loss:13.1812 Train Acc:99.37% Val Acc:90.29% Train F1:0.9937 Val F1:0.9022
# Epoch 93/100 - Loss:13.3840 Train Acc:99.28% Val Acc:58.03% Train F1:0.9928 Val F1:0.4928
# Epoch 94/100 - Loss:11.8091 Train Acc:99.53% Val Acc:89.71% Train F1:0.9953 Val F1:0.8964
# Epoch 95/100 - Loss:14.3021 Train Acc:99.19% Val Acc:80.15% Train F1:0.9919 Val F1:0.7943
# Epoch 96/100 - Loss:13.4492 Train Acc:99.41% Val Acc:71.68% Train F1:0.9941 Val F1:0.6924
# Epoch 97/100 - Loss:14.1710 Train Acc:99.44% Val Acc:91.39% Train F1:0.9944 Val F1:0.9136
# Epoch 98/100 - Loss:13.5025 Train Acc:99.19% Val Acc:57.52% Train F1:0.9919 Val F1:0.4847
# Epoch 99/100 - Loss:10.5863 Train Acc:99.87% Val Acc:93.72% Train F1:0.9987 Val F1:0.9371
# Epoch 100/100 - Loss:14.0530 Train Acc:99.06% Val Acc:87.66% Train F1:0.9906 Val F1:0.8753
# Training time: 0:01:58.584694

# %% [markdown]
# # **Attention1D(C, r=32)**

# %%
# ============================================================
# EEG FEW-SHOT LEARNING FRAMEWORK
# Sobel + Attention + KAN + Deep Supervision
# Train/Validation + ROC + PR + IEEE Figures
# ============================================================

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    auc,
    precision_recall_curve
)

# ============================================================
# DEVICE
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# LOAD DATA
# ============================================================

mat = sio.loadmat("SEED_VIG.mat")

X = mat["EEGsample"].astype(np.float32)
y = mat["substate"].squeeze()

X = (X - X.mean()) / (X.std() + 1e-6)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# ============================================================
# DATASET
# ============================================================

class EEGDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_loader = DataLoader(EEGDataset(X_train, y_train), batch_size=32, shuffle=True)
val_loader   = DataLoader(EEGDataset(X_val, y_val), batch_size=32, shuffle=False)

# ============================================================
# SOBEL PROJECTION
# ============================================================

class Sobel1D(nn.Module):
    def __init__(self):
        super().__init__()
        k = torch.tensor([[[-1, 0, 1]]], dtype=torch.float32)
        self.weight = nn.Parameter(k, requires_grad=False)

    def forward(self, x):
        B, C, T = x.shape
        out = []
        for c in range(C):
            out.append(F.conv1d(x[:, c:c+1], self.weight, padding=1))
        return torch.cat(out, dim=1).abs()

# ============================================================
# ATTENTION
# ============================================================

class Attention1D(nn.Module):
    def __init__(self, C, r=32):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(C, C // r)
        self.fc2 = nn.Linear(C // r, C)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        B, C, T = x.shape
        y = self.pool(x).view(B, C)
        y = F.relu(self.fc1(y))
        y = self.sigmoid(self.fc2(y)).view(B, C, 1)
        return x * y

# ============================================================
# KAN MIXER
# ============================================================

class KAN(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.fc1 = nn.Linear(dim, dim * 2)
        self.fc2 = nn.Linear(dim * 2, dim)
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        r = x
        x = self.norm(x)
        x = F.gelu(self.fc1(x))
        x = self.fc2(x)
        return x + r

# ============================================================
# ENCODER
# ============================================================

class Encoder(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.sobel = Sobel1D()

        self.conv1 = nn.Conv1d(17, 32, 5, padding=2)
        self.conv2 = nn.Conv1d(32, 64, 5, padding=2)
        self.conv3 = nn.Conv1d(64, 128, 5, padding=2)

        self.bn1 = nn.BatchNorm1d(32)
        self.bn2 = nn.BatchNorm1d(64)
        self.bn3 = nn.BatchNorm1d(128)

        self.att1 = Attention1D(32)
        self.att2 = Attention1D(64)
        self.att3 = Attention1D(128)

        self.pool = nn.MaxPool1d(2)

        self.kan = KAN(128)

        self.ds1 = nn.Linear(32, num_classes)
        self.ds2 = nn.Linear(64, num_classes)
        self.ds3 = nn.Linear(128, num_classes)

    def forward(self, x):

        x = x + self.sobel(x)

        x1 = self.pool(self.att1(F.relu(self.bn1(self.conv1(x)))))
        x2 = self.pool(self.att2(F.relu(self.bn2(self.conv2(x1)))))
        x3 = self.pool(self.att3(F.relu(self.bn3(self.conv3(x2)))))

        f1 = F.adaptive_avg_pool1d(x1, 1).squeeze(-1)
        f2 = F.adaptive_avg_pool1d(x2, 1).squeeze(-1)
        f3 = F.adaptive_avg_pool1d(x3, 1).squeeze(-1)

        f3 = self.kan(f3)

        return f3, self.ds1(f1), self.ds2(f2), self.ds3(f3)

# ============================================================
# MODEL
# ============================================================

num_classes = len(np.unique(y))

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.enc = Encoder(num_classes)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        f, d1, d2, d3 = self.enc(x)
        return self.fc(f), [d1, d2, d3]

model = Model().to(device)

# ============================================================
# LOSS + OPT
# ============================================================

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# ============================================================
# HISTORY
# ============================================================

history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": [],
    "train_f1": [],
    "val_f1": []
}

# ============================================================
# TRAINING
# ============================================================

start_time = datetime.now()
num_epochs = 100

for epoch in range(num_epochs):

    # ================= TRAIN =================
    model.train()
    train_p, train_y = [], []
    train_loss = 0

    for x, yb in train_loader:
        x, yb = x.to(device), yb.to(device)

        optimizer.zero_grad()

        logits, ds = model(x)

        loss = criterion(logits, yb)
        for d in ds:
            loss += 0.3 * criterion(d, yb)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        train_p.extend(torch.argmax(logits, 1).cpu().numpy())
        train_y.extend(yb.cpu().numpy())

    # ================= VAL =================
    model.eval()
    val_p, val_y = [], []
    val_loss = 0

    with torch.no_grad():
        for x, yb in val_loader:
            x, yb = x.to(device), yb.to(device)

            logits, _ = model(x)

            loss = criterion(logits, yb)
            val_loss += loss.item()

            val_p.extend(torch.argmax(logits, 1).cpu().numpy())
            val_y.extend(yb.cpu().numpy())

    # ================= METRICS =================
    tr_acc = accuracy_score(train_y, train_p) * 100
    va_acc = accuracy_score(val_y, val_p) * 100

    tr_f1 = f1_score(train_y, train_p, average='weighted')
    va_f1 = f1_score(val_y, val_p, average='weighted')

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(va_acc)
    history["train_f1"].append(tr_f1)
    history["val_f1"].append(va_f1)

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Loss:{train_loss:.4f} "
          f"Train Acc:{tr_acc:.2f}% "
          f"Val Acc:{va_acc:.2f}% "
          f"Train F1:{tr_f1:.4f} "
          f"Val F1:{va_f1:.4f}")

print("Training time:", datetime.now() - start_time)

# ============================================================
# VISUALIZATION (BLUE=VAL, ORANGE=TRAIN)
# ============================================================

epochs = range(num_epochs)

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

# LOSS
ax[0,0].plot(history["train_loss"], color='orange')
ax[0,0].plot(history["val_loss"], color='blue')
ax[0,0].set_title("Loss")

# ACC
ax[0,1].plot(history["train_acc"], color='orange')
ax[0,1].plot(history["val_acc"], color='blue')
ax[0,1].set_title("Accuracy")

# F1
ax[0,2].plot(history["train_f1"], color='orange')
ax[0,2].plot(history["val_f1"], color='blue')
ax[0,2].set_title("F1-score")

plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Epoch 1/100 - Loss:88.3798 Train Acc:83.32% Val Acc:50.07% Train F1:0.8332 Val F1:0.3350
# Epoch 2/100 - Loss:69.5658 Train Acc:89.36% Val Acc:73.43% Train F1:0.8936 Val F1:0.7169
# Epoch 3/100 - Loss:62.8052 Train Acc:91.05% Val Acc:66.28% Train F1:0.9105 Val F1:0.6208
# Epoch 4/100 - Loss:54.3974 Train Acc:93.24% Val Acc:88.32% Train F1:0.9324 Val F1:0.8832
# Epoch 5/100 - Loss:50.6443 Train Acc:92.83% Val Acc:90.73% Train F1:0.9283 Val F1:0.9068
# Epoch 6/100 - Loss:49.6322 Train Acc:93.71% Val Acc:89.49% Train F1:0.9371 Val F1:0.8945
# Epoch 7/100 - Loss:45.2300 Train Acc:94.37% Val Acc:57.66% Train F1:0.9437 Val F1:0.4865
# Epoch 8/100 - Loss:42.9092 Train Acc:94.52% Val Acc:55.26% Train F1:0.9452 Val F1:0.4433
# Epoch 9/100 - Loss:42.5151 Train Acc:93.99% Val Acc:93.43% Train F1:0.9399 Val F1:0.9342
# Epoch 10/100 - Loss:39.8833 Train Acc:94.93% Val Acc:92.55% Train F1:0.9493 Val F1:0.9254
# Epoch 11/100 - Loss:35.1291 Train Acc:96.28% Val Acc:89.05% Train F1:0.9628 Val F1:0.8902
# Epoch 12/100 - Loss:39.6470 Train Acc:95.12% Val Acc:87.52% Train F1:0.9512 Val F1:0.8736
# Epoch 13/100 - Loss:37.3245 Train Acc:95.31% Val Acc:68.69% Train F1:0.9531 Val F1:0.6621
# Epoch 14/100 - Loss:35.2107 Train Acc:96.06% Val Acc:93.72% Train F1:0.9606 Val F1:0.9372
# Epoch 15/100 - Loss:35.4898 Train Acc:95.34% Val Acc:85.77% Train F1:0.9534 Val F1:0.8561
# Epoch 16/100 - Loss:33.8628 Train Acc:95.87% Val Acc:82.34% Train F1:0.9587 Val F1:0.8226
# Epoch 17/100 - Loss:33.0747 Train Acc:96.18% Val Acc:79.71% Train F1:0.9618 Val F1:0.7897
# Epoch 18/100 - Loss:34.8142 Train Acc:95.62% Val Acc:87.15% Train F1:0.9562 Val F1:0.8698
# Epoch 19/100 - Loss:29.4875 Train Acc:96.81% Val Acc:67.59% Train F1:0.9681 Val F1:0.6416
# Epoch 20/100 - Loss:28.0602 Train Acc:97.09% Val Acc:53.65% Train F1:0.9709 Val F1:0.4117
# Epoch 21/100 - Loss:31.4786 Train Acc:96.09% Val Acc:73.87% Train F1:0.9609 Val F1:0.7204
# Epoch 22/100 - Loss:29.9888 Train Acc:96.53% Val Acc:66.57% Train F1:0.9653 Val F1:0.6261
# Epoch 23/100 - Loss:28.3746 Train Acc:97.28% Val Acc:65.77% Train F1:0.9728 Val F1:0.6193
# Epoch 24/100 - Loss:27.7318 Train Acc:96.71% Val Acc:82.41% Train F1:0.9671 Val F1:0.8201
# Epoch 25/100 - Loss:27.0464 Train Acc:97.12% Val Acc:93.43% Train F1:0.9712 Val F1:0.9343
# Epoch 26/100 - Loss:28.5375 Train Acc:96.53% Val Acc:88.83% Train F1:0.9653 Val F1:0.8871
# Epoch 27/100 - Loss:26.0099 Train Acc:97.65% Val Acc:82.85% Train F1:0.9765 Val F1:0.8237
# Epoch 28/100 - Loss:24.2749 Train Acc:97.81% Val Acc:90.73% Train F1:0.9781 Val F1:0.9071
# Epoch 29/100 - Loss:24.5739 Train Acc:97.65% Val Acc:54.16% Train F1:0.9765 Val F1:0.4206
# Epoch 30/100 - Loss:24.5808 Train Acc:97.87% Val Acc:92.63% Train F1:0.9787 Val F1:0.9263
# Epoch 31/100 - Loss:28.4143 Train Acc:96.21% Val Acc:71.39% Train F1:0.9621 Val F1:0.6931
# Epoch 32/100 - Loss:22.3965 Train Acc:98.09% Val Acc:84.01% Train F1:0.9809 Val F1:0.8370
# Epoch 33/100 - Loss:22.9761 Train Acc:98.15% Val Acc:93.94% Train F1:0.9815 Val F1:0.9394
# Epoch 34/100 - Loss:22.6025 Train Acc:98.28% Val Acc:91.53% Train F1:0.9828 Val F1:0.9150
# Epoch 35/100 - Loss:25.5420 Train Acc:97.22% Val Acc:93.36% Train F1:0.9722 Val F1:0.9334
# Epoch 36/100 - Loss:22.3653 Train Acc:97.90% Val Acc:91.68% Train F1:0.9790 Val F1:0.9167
# Epoch 37/100 - Loss:24.4286 Train Acc:98.12% Val Acc:62.26% Train F1:0.9812 Val F1:0.5622
# Epoch 38/100 - Loss:23.7410 Train Acc:97.56% Val Acc:50.73% Train F1:0.9756 Val F1:0.3506
# Epoch 39/100 - Loss:20.9343 Train Acc:98.03% Val Acc:59.56% Train F1:0.9803 Val F1:0.5269
# Epoch 40/100 - Loss:22.4698 Train Acc:98.19% Val Acc:85.91% Train F1:0.9819 Val F1:0.8589
# Epoch 41/100 - Loss:21.8708 Train Acc:97.90% Val Acc:78.76% Train F1:0.9790 Val F1:0.7812
# Epoch 42/100 - Loss:23.5233 Train Acc:97.62% Val Acc:71.61% Train F1:0.9762 Val F1:0.6941
# Epoch 43/100 - Loss:19.0124 Train Acc:98.81% Val Acc:60.36% Train F1:0.9881 Val F1:0.5354
# Epoch 44/100 - Loss:20.6856 Train Acc:98.31% Val Acc:88.47% Train F1:0.9831 Val F1:0.8835
# Epoch 45/100 - Loss:16.8938 Train Acc:99.37% Val Acc:82.70% Train F1:0.9937 Val F1:0.8227
# Epoch 46/100 - Loss:22.1065 Train Acc:98.22% Val Acc:89.93% Train F1:0.9822 Val F1:0.8986
# Epoch 47/100 - Loss:19.0131 Train Acc:98.78% Val Acc:94.38% Train F1:0.9878 Val F1:0.9438
# Epoch 48/100 - Loss:19.6725 Train Acc:98.72% Val Acc:78.03% Train F1:0.9872 Val F1:0.7709
# Epoch 49/100 - Loss:19.8612 Train Acc:98.50% Val Acc:93.50% Train F1:0.9850 Val F1:0.9349
# Epoch 50/100 - Loss:18.3109 Train Acc:99.09% Val Acc:93.50% Train F1:0.9909 Val F1:0.9349
# Epoch 51/100 - Loss:19.2829 Train Acc:98.53% Val Acc:64.89% Train F1:0.9853 Val F1:0.6036
# Epoch 52/100 - Loss:17.9268 Train Acc:99.03% Val Acc:88.76% Train F1:0.9903 Val F1:0.8872
# Epoch 53/100 - Loss:18.7011 Train Acc:98.94% Val Acc:64.67% Train F1:0.9894 Val F1:0.6044
# Epoch 54/100 - Loss:18.1213 Train Acc:98.81% Val Acc:87.08% Train F1:0.9881 Val F1:0.8702
# Epoch 55/100 - Loss:18.3007 Train Acc:98.97% Val Acc:93.72% Train F1:0.9897 Val F1:0.9371
# Epoch 56/100 - Loss:17.0104 Train Acc:98.94% Val Acc:90.58% Train F1:0.9894 Val F1:0.9058
# Epoch 57/100 - Loss:17.8158 Train Acc:98.87% Val Acc:93.14% Train F1:0.9887 Val F1:0.9313
# Epoch 58/100 - Loss:17.8541 Train Acc:98.69% Val Acc:91.82% Train F1:0.9869 Val F1:0.9180
# Epoch 59/100 - Loss:17.5115 Train Acc:98.97% Val Acc:66.06% Train F1:0.9897 Val F1:0.6225
# Epoch 60/100 - Loss:17.2415 Train Acc:98.84% Val Acc:84.16% Train F1:0.9884 Val F1:0.8401
# Epoch 61/100 - Loss:17.1282 Train Acc:99.19% Val Acc:87.08% Train F1:0.9919 Val F1:0.8690
# Epoch 62/100 - Loss:16.4672 Train Acc:99.16% Val Acc:67.81% Train F1:0.9916 Val F1:0.6476
# Epoch 63/100 - Loss:17.6482 Train Acc:99.03% Val Acc:79.05% Train F1:0.9903 Val F1:0.7832
# Epoch 64/100 - Loss:15.7913 Train Acc:99.16% Val Acc:93.36% Train F1:0.9916 Val F1:0.9335
# Epoch 65/100 - Loss:15.4725 Train Acc:99.37% Val Acc:89.20% Train F1:0.9937 Val F1:0.8912
# Epoch 66/100 - Loss:15.0192 Train Acc:99.34% Val Acc:94.16% Train F1:0.9934 Val F1:0.9416
# Epoch 67/100 - Loss:16.8609 Train Acc:99.19% Val Acc:94.38% Train F1:0.9919 Val F1:0.9438
# Epoch 68/100 - Loss:14.7472 Train Acc:99.59% Val Acc:95.11% Train F1:0.9959 Val F1:0.9511
# Epoch 69/100 - Loss:15.3567 Train Acc:99.22% Val Acc:64.60% Train F1:0.9922 Val F1:0.5985
# Epoch 70/100 - Loss:17.8319 Train Acc:98.78% Val Acc:93.36% Train F1:0.9878 Val F1:0.9335
# Epoch 71/100 - Loss:16.9013 Train Acc:98.97% Val Acc:93.80% Train F1:0.9897 Val F1:0.9380
# Epoch 72/100 - Loss:16.1775 Train Acc:99.25% Val Acc:93.50% Train F1:0.9925 Val F1:0.9350
# Epoch 73/100 - Loss:16.7806 Train Acc:99.31% Val Acc:93.28% Train F1:0.9931 Val F1:0.9327
# Epoch 74/100 - Loss:14.8779 Train Acc:99.59% Val Acc:92.55% Train F1:0.9959 Val F1:0.9255
# Epoch 75/100 - Loss:18.4240 Train Acc:98.72% Val Acc:76.50% Train F1:0.9872 Val F1:0.7533
# Epoch 76/100 - Loss:15.1098 Train Acc:99.41% Val Acc:85.69% Train F1:0.9941 Val F1:0.8552
# Epoch 77/100 - Loss:14.7122 Train Acc:99.34% Val Acc:94.74% Train F1:0.9934 Val F1:0.9474
# Epoch 78/100 - Loss:16.4477 Train Acc:98.87% Val Acc:92.12% Train F1:0.9887 Val F1:0.9209
# Epoch 79/100 - Loss:14.1178 Train Acc:99.50% Val Acc:82.99% Train F1:0.9950 Val F1:0.8279
# Epoch 80/100 - Loss:16.6754 Train Acc:99.00% Val Acc:56.79% Train F1:0.9900 Val F1:0.4774
# Epoch 81/100 - Loss:16.2596 Train Acc:99.25% Val Acc:93.14% Train F1:0.9925 Val F1:0.9313
# Epoch 82/100 - Loss:14.5896 Train Acc:99.41% Val Acc:92.70% Train F1:0.9941 Val F1:0.9268
# Epoch 83/100 - Loss:13.2510 Train Acc:99.75% Val Acc:53.36% Train F1:0.9975 Val F1:0.4060
# Epoch 84/100 - Loss:16.2462 Train Acc:99.16% Val Acc:93.65% Train F1:0.9916 Val F1:0.9364
# Epoch 85/100 - Loss:14.6154 Train Acc:99.25% Val Acc:84.31% Train F1:0.9925 Val F1:0.8400
# Epoch 86/100 - Loss:14.3205 Train Acc:99.59% Val Acc:88.47% Train F1:0.9959 Val F1:0.8837
# Epoch 87/100 - Loss:14.7927 Train Acc:99.16% Val Acc:94.38% Train F1:0.9916 Val F1:0.9437
# Epoch 88/100 - Loss:15.2152 Train Acc:99.22% Val Acc:86.79% Train F1:0.9922 Val F1:0.8667
# Epoch 89/100 - Loss:13.5361 Train Acc:99.69% Val Acc:94.89% Train F1:0.9969 Val F1:0.9489
# Epoch 90/100 - Loss:13.7810 Train Acc:99.37% Val Acc:89.71% Train F1:0.9937 Val F1:0.8971
# Epoch 91/100 - Loss:13.5395 Train Acc:99.44% Val Acc:90.36% Train F1:0.9944 Val F1:0.9032
# Epoch 92/100 - Loss:15.8708 Train Acc:99.16% Val Acc:62.12% Train F1:0.9916 Val F1:0.5611
# Epoch 93/100 - Loss:14.0985 Train Acc:99.28% Val Acc:92.85% Train F1:0.9928 Val F1:0.9284
# Epoch 94/100 - Loss:13.1503 Train Acc:99.44% Val Acc:94.01% Train F1:0.9944 Val F1:0.9401
# Epoch 95/100 - Loss:13.6491 Train Acc:99.44% Val Acc:52.63% Train F1:0.9944 Val F1:0.3956
# Epoch 96/100 - Loss:13.9154 Train Acc:99.34% Val Acc:90.88% Train F1:0.9934 Val F1:0.9086
# Epoch 97/100 - Loss:14.6784 Train Acc:99.16% Val Acc:89.78% Train F1:0.9916 Val F1:0.8970
# Epoch 98/100 - Loss:12.9528 Train Acc:99.69% Val Acc:54.09% Train F1:0.9969 Val F1:0.4221
# Epoch 99/100 - Loss:13.9384 Train Acc:99.34% Val Acc:79.85% Train F1:0.9934 Val F1:0.7923
# Epoch 100/100 - Loss:15.2160 Train Acc:99.41% Val Acc:92.55% Train F1:0.9941 Val F1:0.9254
# Training time: 0:01:56.789462
